# %% [markdown]
# ### pip install & import

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # 데이터 준비

# %% [markdown]
# ### 최종데이터 불러오기
# - movie_resize_회귀 : 전국 관객수 10000명 초과, 관객수 100000 미만 전국 스크린수 50 초과

# %%
movie_final_회귀 = pd.read_csv('../0_data/movie_final_reg.csv',encoding='utf-8')

# %%
movie_final_회귀['전국 스크린수'][56]
# Out:
# 120

# %% [markdown]
# ### 스케일링

# %%
# '전국 스크린수'와 '총 관객수' 데이터 스케일링: RobustScaler()사용

robust_scaler = RobustScaler()

A_n = robust_scaler.fit_transform(movie_final_회귀['전국 스크린수'].values.reshape(-1,1))
movie_final_회귀.insert(0, '전국 스크린수_1', A_n)
movie_final_회귀.drop(['전국 스크린수'], axis=1, inplace=True)

A_n1 = robust_scaler.fit_transform(movie_final_회귀['총 관객수'].values.reshape(-1,1))
movie_final_회귀.insert(0, '총 관객수_1', A_n1)
movie_final_회귀.drop(['총 관객수'], axis=1, inplace=True)

movie_final_회귀.columns
# Out:
# Index(['총 관객수_1', '전국 스크린수_1', 'Unnamed: 0', '순번', '영화명', '감독', '배급사', '개봉일',
#        '영화형태', '국적', '전국 매출액', '전국 관객수', '서울 매출액', '서울 관객수', '장르', '등급',
#        '영화구분', '연도', '월', '계절', '코로나', '출연', '평점', '감독_흥행', '배급사_흥행',
#        '주연배우_흥행'],
#       dtype='object')

# %% [markdown]
# ### 라벨링

# %%
# 명목형 자료들을 라벨링: LabelEncoder() 사용

le_form = LabelEncoder()
le_nation = LabelEncoder()
le_genre = LabelEncoder()
le_rating = LabelEncoder()
le_class = LabelEncoder()
le_season = LabelEncoder()

movie_labels = movie_final_회귀.copy()
movie_labels['영화형태'] = le_form.fit_transform(movie_final_회귀['영화형태'])
movie_labels['국적'] = le_nation.fit_transform(movie_final_회귀['국적'])
movie_labels['장르'] = le_genre.fit_transform(movie_final_회귀['장르'])
movie_labels['등급'] = le_rating.fit_transform(movie_final_회귀['등급'])
movie_labels['영화구분'] = le_class.fit_transform(movie_final_회귀['영화구분'])
movie_labels['계절'] = le_season.fit_transform(movie_final_회귀['계절'])
movie_labels.drop(['Unnamed: 0'],axis=1,inplace=True)
movie_labels.head(3)
# Out:
#     총 관객수_1  전국 스크린수_1    순번     영화명      감독         배급사         개봉일  영화형태  \
# 0  0.018839   1.959732  2575  미니특공대X     이영준     삼지애니메이션  2018-03-22     2
# 1 -0.854008  -0.033557  2578     알파독  닉 카사베츠        싸이더스  2009-01-29     2
# 2 -1.463612   3.348993  2583     엘비스  바즈 루어만  워너브러더스 코리아  2022-07-13     2
#
#    국적      전국 매출액  ...  영화구분    연도  월  계절  코로나  \
# 0   7   744858200  ...     1  2018  3   2    0
# 1   2   648950794  ...     1  2009  1   1    0
# 2   2  1070700628  ...     1  2022  7   3    1
#
#                                                   출연    평점  감독_흥행  배급사_흥행  \
# 0                       ['엄상현', '전태열', '이소영', '신용우']  7.55      0       0
# 1  ['에밀 허쉬', '저스틴 팀버레이크', '벤 포스터', '안톤 옐친', '아만다 ...  6.06      0       6
# 2                               ['오스틴 버틀러', '톰 행크스']  8.83      0      10
#
#    주연배우_흥행
# 0        0
# 1        6
# 2        5
#
# [3 rows x 25 columns]

# %% [markdown]
# ### 데이터 및 변수 정리

# %% [markdown]
# #### 1) 데이터 재분배
# 1) movie_labels_etc : train과 val data
# 2) movie_labels_2023 : test data

# %%
# 2003년~2022년 데이터와 2023년 데이터로 나눔
movie_labels_etc = movie_labels[movie_labels['연도']!=2023]
movie_labels_2023 = movie_labels[movie_labels['연도']==2023]

# %%
movie_labels_2023
# Out:
#        총 관객수_1  전국 스크린수_1    순번                               영화명        감독  \
# 56   -1.463612  -0.308725  2652                방탄소년단: 옛 투 컴 인 시네마       오윤동
# 58   -1.463612   2.637584  2655                          어메이징 모리스     토비 젠켈
# 68   -1.463612   2.335570  2668                     두다다쿵: 후후섬의 비밀       김지윤
# 77   -1.463612   2.657718  2681                             다음 소희       정주리
# 358  -1.463612   1.463087  3091                       라일 라일 크로커다일      윌 스펙
# 639  -1.463612  -0.684564  3528                              애프터썬        기타
# 646  -1.463612   0.791946  3541  바다 탐험대 옥토넛 육지수호 대작전 : 열대우림을 지켜라!        기타
# 675  -1.463612   1.899329  3590                     네가 떨어뜨린 푸른 하늘    사이토 유키
# 803  -1.463612   0.073826  3776                              돌핀보이        기타
# 833  -1.463612   0.899329  3823                         천룡팔부: 교봉전       견자단
# 843  -1.463612   0.067114  3838                        3000년의 기다림     조지 밀러
# 942  -1.463612   0.208054  3992                            TAR 타르     토드 필드
# 996  -1.463612  -0.288591  4081  극장판 전생했더니 슬라임이었던 건에 대하여: 홍련의 인연편  키쿠치 야스히토
# 1026 -1.463612   0.342282  4134                 미녀와 야수: 마법에 걸린 왕자        기타
# 1068 -1.463612   1.120805  4199                  어쩌면 우린 헤어졌는지 모른다       형슬우
# 1070 -1.463612   0.100671  4203                            프린스 챠밍    로스 베노커
# 1280 -1.463612   0.046980  4584                   우리 사랑이 향기로 남을 때       임성용
# 1343 -1.463612  -0.597315  4725                        시간을 꿈꾸는 소녀       박혁지
# 1388 -1.463612   0.013423  4819                                트윈  타넬리 무스토넨
#
#                        배급사         개봉일  영화형태  국적      전국 매출액  ...  영화구분    연도  \
# 56               씨제이포디플렉스   2023-02-01     2   7  2031919000  ...     1  2023
# 58                 블루라벨픽쳐스  2023-02-15     2   1   811786302  ...     0  2023
# 68             넥스트엔터테인먼트월드  2023-02-15     2   7   817803025  ...     1  2023
# 77               트윈플러스파트너스  2023-02-08     2   7   847134216  ...     0  2023
# 358   소니픽쳐스엔터테인먼트코리아극장배급지점  2023-01-18     2   2   502081439  ...     1  2023
# 639                그린나래미디어  2023-02-01     2   3   326148634  ...     0  2023
# 646                와이드 릴리즈  2023-02-23     2   3   290132400  ...     0  2023
# 675                 메가박스중앙  2023-02-08     2   4   300531316  ...     1  2023
# 803                와이드 릴리즈  2023-01-25     2   1   226353600  ...     1  2023
# 833                팝엔터테인먼트  2023-01-25     2   0   210773266  ...     1  2023
# 843                  디스테이션  2023-01-04     2   0   224395015  ...     0  2023
# 942       유니버설픽쳐스인터내셔널 코리아  2023-02-22     2   2   208721573  ...     1  2023
# 996                  애니플러스  2023-02-02     2   4   193259734  ...     1  2023
# 1026                  인터파크  2023-02-22     2   0   159255200  ...     0  2023
# 1068             영화특별시에스엠씨  2023-02-08     2   7   177589066  ...     0  2023
# 1070               와이드 릴리즈  2023-01-11     2   2   138765300  ...     0  2023
# 1280                  콘텐츠존  2023-02-08     2   7   115272800  ...     1  2023
# 1343               하이하버픽쳐스  2023-01-11     2   7    85517894  ...     0  2023
# 1388             스튜디오디에이치엘  2023-02-08     2   0    89859242  ...     0  2023
#
#       월  계절  코로나                                                 출연    평점  \
# 56    2   1    0          ['RM', '진', '슈가', '제이홉', '지민', '뷔', '정국']  9.35
# 58    2   1    0  ['휴 로리', '에밀리아 클라크', '데이빗 듈리스', '히메쉬 파텔', '젬마 ...  8.26
# 68    2   1    0  ['이영아', '장경희', '엄상현', '이소영', '이은정', '김서영', '여민...  8.74
# 77    2   1    0                                     ['김시은', '배두나']  9.44
# 358   1   1    0  ['하비에르 바르뎀', '윈슬로우 페글리', '콘스탄스 우', '스쿳 맥네이리', ...  7.96
# 639   2   1    0                               ['폴 메스칼', '프랭키 코리오']  8.45
# 646   2   1    0  ['하성용', '정재헌', '엄상현', '윤승희', '김율', '유동균', '김정은...  2.43
# 675   2   1    0                              ['후쿠모토 리코', '마츠다 겐타']  6.01
# 803   1   1    0                                            ['박시윤']  4.68
# 833   1   1    0                                     ['견자단', '진옥기']  7.38
# 843   1   1    0                              ['틸다 스윈튼', '이드리스 엘바']  7.94
# 942   2   1    0                                        ['케이트 블란쳇']  7.80
# 996   2   1    0     ['우치다 유우마', '후쿠모토 리코', '후루카와 마코토', '토요구치 메구미']  7.27
# 1026  2   1    0                        ['박시윤', '김용', '정성원', '서정익']  7.78
# 1068  2   1    0                       ['이동휘', '정은채', '강길우', '정다은']  8.24
# 1070  1   1    0  ['데미 로바토', '윌머 발더라마', '시아', '에이브릴 라빈', '애슐리 티스...  6.34
# 1280  2   1    0                                     ['윤시윤', '설인아']  6.80
# 1343  1   1    0                                     ['권수진', '이경원']  7.99
# 1388  2   1    0                   ['테레사 팔머', '스티븐 크리', '트리스탄 루게리']  5.73
#
#       감독_흥행  배급사_흥행  주연배우_흥행
# 56        0       0       17
# 58        0       0        4
# 68        0      10        0
# 77        0       0        9
# 358       0       9        4
# 639       0       0        0
# 646       0       0        6
# 675       0       0        0
# 803       0       0        0
# 833       0       0        0
# 843       5       8       17
# 942       0       8        7
# 996       0       0        0
# 1026      0       0        0
# 1068      0       0       10
# 1070      0       0        5
# 1280      0       0        0
# 1343      0       0        0
# 1388      0       4        0
#
# [19 rows x 25 columns]

# %% [markdown]
# #### 2) 독립 및 종속 변수 선언

# %%
# 사용하지 않는 컬럼 제거

not_used = ['영화명', '감독', '배급사', '영화형태', '개봉일', '영화구분', '월']

movie_DL = movie_labels_etc.drop(not_used, axis=1) # 2003~2022 데이터 main
movie_DL2 = movie_labels_2023.drop(not_used, axis=1) # 2023년 test

# %%
# 독립 변수와 종속 변수 나눔

종속 = movie_DL[['전국 관객수']].copy()
종속['전국 관객수'] = 종속['전국 관객수'] / 1000 

종속_2023 = movie_DL2[['전국 관객수']].copy()
종속_2023['전국 관객수'] = 종속_2023['전국 관객수'] / 1000 


독립 = movie_DL[['장르', '등급', '감독_흥행','총 관객수_1',
               '배급사_흥행','주연배우_흥행','계절', '전국 스크린수_1','코로나']].copy()

독립_2023 = movie_DL2[['장르', '등급', '감독_흥행','총 관객수_1',
               '배급사_흥행','주연배우_흥행','계절', '전국 스크린수_1','코로나']].copy()

# %% [markdown]
# #### 3) train, validation용 데이터 나누기

# %%
# train, validation 데이터 나눔

from sklearn.model_selection import train_test_split
train_input, val_input, train_target, val_target = train_test_split(독립,종속,test_size=0.25, random_state=42)

# %% [markdown]
# # 모델 구조 만들기

# %%
# 딥러닝 층 여기가 중요

X = tf.keras.layers.Input(shape=[len(train_input.columns)])

H = tf.keras.layers.Dense(90)(X)
H = tf.keras.layers.BatchNormalization(epsilon=1e-5)(H)
H = tf.keras.layers.Activation(tf.nn.swish)(H)
# dropout = tf.keras.layers.Dropout(rate=0.2)(H)

H = tf.keras.layers.Dense(90)(H)
H = tf.keras.layers.BatchNormalization(epsilon=1e-5)(H)
H = tf.keras.layers.Activation(tf.nn.swish)(H)
# dropout = tf.keras.layers.Dropout(rate=0.2)(H)

H = tf.keras.layers.Dense(90)(H)
H = tf.keras.layers.BatchNormalization(epsilon=1e-5)(H)
H = tf.keras.layers.Activation(tf.nn.swish)(H)
dropout = tf.keras.layers.Dropout(rate=0.2)(H)

Y = tf.keras.layers.Dense(1)(dropout)
model = tf.keras.models.Model(X,Y)

Adagrad = tf.keras.optimizers.Adagrad(learning_rate=0.9,  epsilon=1e-6)
model.compile(optimizer=Adagrad,loss='mae')

# %% [markdown]
# # 모델 학습시키기

# %%
# 훈련
history = model.fit(train_input,train_target,batch_size=128,epochs=100,validation_data=(val_input,val_target))
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 19ms/step - loss: 28.3420 - val_loss: 821.3970
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 20.7875 - val_loss: 56.0274
# Epoch 3/100
# 9/9 [==============================] - 0s 5ms/step - loss: 20.4853 - val_loss: 35.6440
# Epoch 4/100
# 9/9 [==============================] - 0s 5ms/step - loss: 19.5457 - val_loss: 93.6292
# Epoch 5/100
# 9/9 [==============================] - 0s 6ms/step - loss: 19.2256 - val_loss: 22.3176
# Epoch 6/100
# 9/9 [==============================] - 0s 6ms/step - loss: 18.6107 - val_loss: 26.5177
# Epoch 7/100
# 9/9 [==============================] - 0s 6ms/step - loss: 18.3218 - val_loss: 63.0984
# Epoch 8/100
# 9/9 [==============================] - 0s 6ms/step - loss: 18.6968 - val_loss: 19.6629
# Epoch 9/100
# 9/9 [==============================] - 0s 6ms/step - loss: 18.5266 - val_loss: 25.2654
# Epoch 10/100
# 9/9 [==============================] - 0s 6ms/step - loss: 18.1579 - val_loss: 42.3335
# Epoch 11/100
# 9/9 [==============================] - 0s 5ms/step - loss: 17.3718 - val_loss: 20.6437
# Epoch 12/100
# 9/9 [==============================] - 0s 6ms/step - loss: 18.1532 - val_loss: 16.4819
# Epoch 13/100
# 9/9 [==============================] - 0s 6ms/step - loss: 17.8440 - val_loss: 23.7804
# Epoch 14/100
# 9/9 [==============================] - 0s 6ms/step - loss: 17.8687 - val_loss: 22.3713
# Epoch 15/100
# 9/9 [==============================] - 0s 6ms/step - loss: 17.2552 - val_loss: 22.1973
# Epoch 16/100
# 9/9 [==============================] - 0s 6ms/step - loss: 16.9378 - val_loss: 16.9836
# Epoch 17/100
# 9/9 [==============================] - 0s 5ms/step - loss: 16.9432 - val_loss: 21.5393
# Epoch 18/100
# 9/9 [==============================] - 0s 6ms/step - loss: 17.2611 - val_loss: 18.2474
# Epoch 19/100
# 9/9 [==============================] - 0s 6ms/step - loss: 16.6581 - val_loss: 27.7158
# Epoch 20/100
# 9/9 [==============================] - 0s 6ms/step - loss: 17.1298 - val_loss: 19.4582
# Epoch 21/100
# 9/9 [==============================] - 0s 5ms/step - loss: 17.0968 - val_loss: 17.5519
# Epoch 22/100
# 9/9 [==============================] - 0s 6ms/step - loss: 16.5548 - val_loss: 16.0240
# Epoch 23/100
# 9/9 [==============================] - 0s 6ms/step - loss: 16.0455 - val_loss: 15.8884
# Epoch 24/100
# 9/9 [==============================] - 0s 6ms/step - loss: 16.6967 - val_loss: 23.9828
# Epoch 25/100
# 9/9 [==============================] - 0s 6ms/step - loss: 16.5412 - val_loss: 17.5578
# Epoch 26/100
# 9/9 [==============================] - 0s 5ms/step - loss: 16.1346 - val_loss: 20.5585
# Epoch 27/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.9184 - val_loss: 16.4999
# Epoch 28/100
# 9/9 [==============================] - 0s 6ms/step - loss: 16.2088 - val_loss: 15.9992
# Epoch 29/100
# 9/9 [==============================] - 0s 9ms/step - loss: 16.2739 - val_loss: 15.8623
# Epoch 30/100
# 9/9 [==============================] - 0s 5ms/step - loss: 15.8968 - val_loss: 16.2160
# Epoch 31/100
# 9/9 [==============================] - 0s 5ms/step - loss: 16.2381 - val_loss: 21.3811
# Epoch 32/100
# 9/9 [==============================] - 0s 5ms/step - loss: 16.1341 - val_loss: 16.7342
# Epoch 33/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.7434 - val_loss: 16.2113
# Epoch 34/100
# 9/9 [==============================] - 0s 5ms/step - loss: 15.8934 - val_loss: 16.6942
# Epoch 35/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.9652 - val_loss: 18.7612
# Epoch 36/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.9031 - val_loss: 17.6465
# Epoch 37/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.7420 - val_loss: 15.2350
# Epoch 38/100
# 9/9 [==============================] - 0s 8ms/step - loss: 15.9239 - val_loss: 17.4865
# Epoch 39/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.3222 - val_loss: 15.2048
# Epoch 40/100
# 9/9 [==============================] - 0s 5ms/step - loss: 15.8986 - val_loss: 17.1907
# Epoch 41/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.7974 - val_loss: 15.3433
# Epoch 42/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.6449 - val_loss: 17.7104
# Epoch 43/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.6419 - val_loss: 17.4721
# Epoch 44/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.8264 - val_loss: 15.5096
# Epoch 45/100
# 9/9 [==============================] - 0s 5ms/step - loss: 15.2706 - val_loss: 15.3702
# Epoch 46/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.2104 - val_loss: 15.5673
# Epoch 47/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.5752 - val_loss: 15.4517
# Epoch 48/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.3447 - val_loss: 16.6585
# Epoch 49/100
# 9/9 [==============================] - 0s 11ms/step - loss: 15.7747 - val_loss: 15.0973
# Epoch 50/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.5246 - val_loss: 16.5972
# Epoch 51/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.5186 - val_loss: 18.2661
# Epoch 52/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.5459 - val_loss: 15.8431
# Epoch 53/100
# 9/9 [==============================] - 0s 7ms/step - loss: 15.5284 - val_loss: 15.4680
# Epoch 54/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.3811 - val_loss: 17.5448
# Epoch 55/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.6915 - val_loss: 15.4419
# Epoch 56/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.1109 - val_loss: 15.6604
# Epoch 57/100
# 9/9 [==============================] - 0s 7ms/step - loss: 15.2174 - val_loss: 15.0079
# Epoch 58/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.2413 - val_loss: 15.5258
# Epoch 59/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.5406 - val_loss: 15.1893
# Epoch 60/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.1925 - val_loss: 15.1899
# Epoch 61/100
# 9/9 [==============================] - 0s 9ms/step - loss: 15.3304 - val_loss: 16.6518
# Epoch 62/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.4304 - val_loss: 14.9405
# Epoch 63/100
# 9/9 [==============================] - 0s 5ms/step - loss: 15.1250 - val_loss: 15.9727
# Epoch 64/100
# 9/9 [==============================] - 0s 5ms/step - loss: 15.0803 - val_loss: 16.1217
# Epoch 65/100
# 9/9 [==============================] - 0s 5ms/step - loss: 15.2556 - val_loss: 18.8396
# Epoch 66/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.2953 - val_loss: 14.9412
# Epoch 67/100
# 9/9 [==============================] - 0s 7ms/step - loss: 14.8697 - val_loss: 15.8053
# Epoch 68/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.2278 - val_loss: 14.7593
# Epoch 69/100
# 9/9 [==============================] - 0s 5ms/step - loss: 15.2589 - val_loss: 15.3607
# Epoch 70/100
# 9/9 [==============================] - 0s 5ms/step - loss: 15.3713 - val_loss: 16.2296
# Epoch 71/100
# 9/9 [==============================] - 0s 5ms/step - loss: 14.8880 - val_loss: 16.3887
# Epoch 72/100
# 9/9 [==============================] - 0s 7ms/step - loss: 15.1091 - val_loss: 15.6659
# Epoch 73/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.0002 - val_loss: 15.4839
# Epoch 74/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.1449 - val_loss: 17.0891
# Epoch 75/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.0272 - val_loss: 15.6727
# Epoch 76/100
# 9/9 [==============================] - 0s 7ms/step - loss: 15.1742 - val_loss: 14.7809
# Epoch 77/100
# 9/9 [==============================] - 0s 6ms/step - loss: 14.9851 - val_loss: 15.0664
# Epoch 78/100
# 9/9 [==============================] - 0s 8ms/step - loss: 14.8478 - val_loss: 16.0103
# Epoch 79/100
# 9/9 [==============================] - 0s 7ms/step - loss: 15.1695 - val_loss: 15.7732
# Epoch 80/100
# 9/9 [==============================] - 0s 7ms/step - loss: 14.8237 - val_loss: 16.1208
# Epoch 81/100
# 9/9 [==============================] - 0s 6ms/step - loss: 14.8155 - val_loss: 15.9779
# Epoch 82/100
# 9/9 [==============================] - 0s 5ms/step - loss: 14.8446 - val_loss: 16.4200
# Epoch 83/100
# 9/9 [==============================] - 0s 7ms/step - loss: 15.2023 - val_loss: 16.1685
# Epoch 84/100
# 9/9 [==============================] - 0s 6ms/step - loss: 14.9618 - val_loss: 15.1573
# Epoch 85/100
# 9/9 [==============================] - 0s 5ms/step - loss: 14.7717 - val_loss: 15.2465
# Epoch 86/100
# 9/9 [==============================] - 0s 5ms/step - loss: 14.9692 - val_loss: 15.3362
# Epoch 87/100
# 9/9 [==============================] - 0s 15ms/step - loss: 14.9357 - val_loss: 17.9239
# Epoch 88/100
# 9/9 [==============================] - 0s 5ms/step - loss: 14.6556 - val_loss: 15.0170
# Epoch 89/100
# 9/9 [==============================] - 0s 6ms/step - loss: 14.7801 - val_loss: 15.2838
# Epoch 90/100
# 9/9 [==============================] - 0s 5ms/step - loss: 14.8089 - val_loss: 18.6708
# Epoch 91/100
# 9/9 [==============================] - 0s 5ms/step - loss: 14.7341 - val_loss: 16.6028
# Epoch 92/100
# 9/9 [==============================] - 0s 7ms/step - loss: 14.6551 - val_loss: 15.8204
# Epoch 93/100
# 9/9 [==============================] - 0s 6ms/step - loss: 15.0258 - val_loss: 16.9191
# Epoch 94/100
# 9/9 [==============================] - 0s 6ms/step - loss: 14.9806 - val_loss: 15.4936
# Epoch 95/100
# 9/9 [==============================] - 0s 6ms/step - loss: 14.8564 - val_loss: 14.7880
# Epoch 96/100
# 9/9 [==============================] - 0s 5ms/step - loss: 14.6851 - val_loss: 16.5471
# Epoch 97/100
# 9/9 [==============================] - 0s 6ms/step - loss: 14.8398 - val_loss: 15.3527
# Epoch 98/100
# 9/9 [==============================] - 0s 6ms/step - loss: 14.5132 - val_loss: 14.7245
# Epoch 99/100
# 9/9 [==============================] - 0s 7ms/step - loss: 14.5945 - val_loss: 15.1270
# Epoch 100/100
# 9/9 [==============================] - 0s 5ms/step - loss: 14.6288 - val_loss: 15.3009

# %% [markdown]
# # 모델을 이용하기

# %% [markdown]
# ### 손실값 그래프 확인

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %% [markdown]
# ### test 세트로 모델 predict 수행

# %%
# 오차율 20%이내인 데이터 갯수 확인하기
pred = model.predict(독립_2023).round(0)

종속_2023['pred'] = pred
종속_2023['오차율'] = (abs(종속_2023['전국 관객수'] - 종속_2023['pred'])) / 종속_2023['전국 관객수'] * 100
len(종속_2023.loc[종속_2023['오차율']<20])
# Out:
# 1/1 [==============================] - 0s 91ms/step
# 13

# %%
종속_2023[:5]
# Out:
#      전국 관객수   pred        오차율
# 56   92.369  105.0  13.674501
# 58   91.833   55.0  40.108676
# 68   90.281   84.0   6.957167
# 77   88.489   69.0  22.024206
# 358  54.192   53.0   2.199587

# %% [markdown]
# ### 모델 저장 및 불러오기

# %%
# model.save("reg_model.h5")
model = tf.keras.models.load_model('../0_data/DL_model/reg_model.h5',compile=False)
