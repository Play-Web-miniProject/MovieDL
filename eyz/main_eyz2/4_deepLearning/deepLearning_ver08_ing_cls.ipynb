# %% [markdown]
# ### pip install & import

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight

from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.layers import Dense, Input, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from keras.models import load_model

# %% [markdown]
# # 데이터 준비

# %% [markdown]
# ### 최종 데이터 불러오기
# * movie_final_분류 : 전국 관객수 80만명 초과, 전국 스크린수 50개 초과

# %%
movie_final_분류 = pd.read_csv('../3_merge_top300/movie_final_cls.csv',encoding='utf-8')

# %% [markdown]
# ### 스케일링

# %%
# 전국 스크린수와 총 관객수를 스케일링: RobustScaler() 사용
# 객체생성
robust_scaler = RobustScaler()

# *** '전국 스크린수'와 '총 관객수' 컬럼을 스케일링 ***
A_n = robust_scaler.fit_transform(movie_final_분류['전국 스크린수'].values.reshape(-1,1))
movie_final_분류.insert(0, '전국 스크린수_scaled', A_n)
movie_final_분류.drop(['전국 스크린수'], axis=1, inplace=True)

A_n1 = robust_scaler.fit_transform(movie_final_분류['총 관객수'].values.reshape(-1,1))
movie_final_분류.insert(0, '총 관객수_scaled', A_n1)
movie_final_분류.drop(['총 관객수'], axis=1, inplace=True)

# 변경이 잘 되었는지 확인
movie_final_분류.columns
# Out:
# Index(['총 관객수_scaled', '전국 스크린수_scaled', 'Unnamed: 0', '순번', '영화명', '감독',
#        '배급사', '개봉일', '영화형태', '국적', '전국 매출액', '전국 관객수', '서울 매출액', '서울 관객수',
#        '장르', '등급', '영화구분', '연도', '월', '계절', '코로나', '출연', '평점', '감독_흥행',
#        '배급사_흥행', '주연배우_흥행'],
#       dtype='object')

# %% [markdown]
# ### 라벨링

# %% [markdown]
# #### 1) 인풋 데이터 라벨링

# %%
# 명목형 자료들을 라벨링: LabelEncoder() 사용

le_form = LabelEncoder()
le_nation = LabelEncoder()
le_genre = LabelEncoder()
le_rating = LabelEncoder()
le_class = LabelEncoder()
le_season = LabelEncoder()
le_year = LabelEncoder()

movie_labels = movie_final_분류.copy()
movie_labels['영화형태'] = le_form.fit_transform(movie_final_분류['영화형태'])
movie_labels['국적'] = le_nation.fit_transform(movie_final_분류['국적'])
movie_labels['장르'] = le_genre.fit_transform(movie_final_분류['장르'])
movie_labels['등급'] = le_rating.fit_transform(movie_final_분류['등급'])
movie_labels['영화구분'] = le_class.fit_transform(movie_final_분류['영화구분'])
movie_labels['계절'] = le_season.fit_transform(movie_final_분류['계절'])
movie_labels['연도'] = le_year.fit_transform(movie_final_분류['연도'])
movie_labels.drop(['Unnamed: 0'],axis=1,inplace=True)
movie_labels.columns
# Out:
# Index(['총 관객수_scaled', '전국 스크린수_scaled', '순번', '영화명', '감독', '배급사', '개봉일',
#        '영화형태', '국적', '전국 매출액', '전국 관객수', '서울 매출액', '서울 관객수', '장르', '등급',
#        '영화구분', '연도', '월', '계절', '코로나', '출연', '평점', '감독_흥행', '배급사_흥행',
#        '주연배우_흥행'],
#       dtype='object')

# %% [markdown]
# #### 2) 타겟 데이터 라벨링

# %%
# target 데이터 라벨링
# 전국 관객수 기준, [100만미만/100만/150만/300만/500만]으로 나누어 라벨링

movie_labels['분류클래스'] = np.where((movie_labels['전국 관객수'].values<1000000), 0, 
                                 np.where((movie_labels['전국 관객수'].values>=1000000) & (movie_labels['전국 관객수'].values<1500000), 1,
                                          np.where((movie_labels['전국 관객수'].values>=1500000) & (movie_labels['전국 관객수'].values<3000000), 2,
                                                   np.where((movie_labels['전국 관객수'].values>=3000000) & (movie_labels['전국 관객수'].values<5000000), 3, 4))))

classes = sorted(movie_labels['분류클래스'].unique())
print(classes)
for i in classes:
    print(i, len(movie_labels[movie_labels['분류클래스']==i]))
# Out:
# [0, 1, 2, 3, 4]
# 0 100
# 1 149
# 2 249
# 3 109
# 4 101

# %% [markdown]
# ### 데이터 및 변수 정리

# %% [markdown]
# #### 1) 독립 및 종속 변수 선언

# %%
# 사용하는 컬럼만 독립변수와 종속변수에 할당
독립 = movie_labels[['장르', '등급', '감독_흥행','총 관객수_scaled',
               '배급사_흥행','주연배우_흥행','계절', '전국 스크린수_scaled','연도','코로나']].copy()

종속 = movie_labels[['분류클래스']].copy()

display(독립.info())
print()
display(종속.describe().round())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   장르              708 non-null    int32
#  1   등급              708 non-null    int32
#  2   감독_흥행           708 non-null    int64
#  3   총 관객수_scaled    708 non-null    float64
#  4   배급사_흥행          708 non-null    int64
#  5   주연배우_흥행         708 non-null    int64
#  6   계절              708 non-null    int32
#  7   전국 스크린수_scaled  708 non-null    float64
#  8   연도              708 non-null    int64
#  9   코로나             708 non-null    int64
# dtypes: float64(2), int32(3), int64(5)
# memory usage: 47.1 KB
# None
#        분류클래스
# count  708.0
# mean     2.0
# std      1.0
# min      0.0
# 25%      1.0
# 50%      2.0
# 75%      3.0
# max      4.0

# %% [markdown]
# #### 2) train, validation, test용 데이터 나누기

# %%
# 1. train 데이터(80%)와 test 데이터(20%)로 나누기
train_input, test_input, train_target, test_target = train_test_split(독립, 종속, test_size=0.05, random_state=31)
print(len(train_input), len(test_input))
# Out:
# 672 36

# %%
# 2. train 데이터를 train 데이터(80%*80%)와 val 데이터(80%*20%)로 나누기
train_input, val_input, train_target, val_target = train_test_split(train_input, train_target, test_size=0.10, random_state=31)
print(len(train_input), len(val_input), len(test_input))
# Out:
# 604 68 36

# %%
# 클래스 별로 고루 분배되었는지 확인
# 분배 잘 안되었으면 split 1, 2 다시 실행

classes = sorted(train_target['분류클래스'].unique())
for i in classes:
    print(i, len(train_target[train_target['분류클래스']==i]))
print()

for i in classes:
    print(i, len(val_target[val_target['분류클래스']==i]))
print()

for i in classes:
    print(i, len(test_target[test_target['분류클래스']==i]))
# Out:
# 0 85
# 1 122
# 2 218
# 3 93
# 4 86
#
# 0 8
# 1 18
# 2 22
# 3 11
# 4 9
#
# 0 7
# 1 9
# 2 9
# 3 5
# 4 6

# %%
# 확인 완료 되었으면 target 데이터 flatten
train_target, val_target, test_target = train_target.to_numpy().flatten(), val_target.to_numpy().flatten(), test_target.to_numpy().flatten()

# %% [markdown]
# # 모델 구조 만들기
# #### 1) 하이퍼파라미터 튜닝

# %%
# 모델 생성 함수
def create_model(learning_rate=0.01, num_layers=4, units=128):
    X = Input(shape=(train_input.shape[1],))
    H = Dense(units, activation = 'relu')(X)
    H = Dense(64, activation = 'relu')(H)
    H = Dense(32, activation = 'relu')(H)
    H = Dense(16, activation = 'relu')(H)
    Y = Dense(5, activation='softmax')(H)
    model = Model(X, Y)
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Keras Classifier 생성
model = KerasClassifier(build_fn=create_model, epochs=200, batch_size=32, verbose=0)

# 하이퍼파라미터 탐색 범위
param_dist = {
    'learning_rate': np.arange(0.001, 0.01, 0.001),
    'num_layers': [2, 3, 4, 5],
    'units': [32, 64, 128, 256]
}

# 랜덤 서치 객체 생성
search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, cv=3, n_iter=20, n_jobs=3, verbose=1)

# 랜덤 서치 수행
search_results = search.fit(train_input, train_target)

# 결과 출력
print('Best Score:', search_results.best_score_)
print('Best Params:', search_results.best_params_)
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_13028\1072662922.py:15: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, epochs=200, batch_size=32, verbose=0)
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best Score: 0.3974188466866811
# Best Params: {'units': 256, 'num_layers': 5, 'learning_rate': 0.006}

# %% [markdown]
# #### (2) 최적의 하이퍼파라미터 적용하여 모델 생성

# %%
X = tf.keras.layers.Input(shape=[len(train_input.columns)])

H = tf.keras.layers.Dense(256, activation=tf.nn.relu)(X)
H = tf.keras.layers.Dense(128, activation=tf.nn.relu)(H)
H = tf.keras.layers.Dense(64, activation=tf.nn.relu)(H)
H = tf.keras.layers.Dense(32, activation=tf.nn.relu)(H)

Y = tf.keras.layers.Dense(5, activation='softmax')(H)
model = tf.keras.models.Model(X,Y)

adam = tf.keras.optimizers.Adam(learning_rate=0.007)
model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %% [markdown]
# # 모델 학습시키기

# %% [markdown]
# ### 클래스별 가중치 적용하여 딥러닝 학습 실행
# 클래스별 편향된 분포를 조정하기 위해 클래스별 가중치를 계산한다.

# %%
# 레이블 클래스 빈도수 계산
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.array([0, 1, 2, 3, 4]), y=train_target)

# 가중치 딕셔너리 생성
class_weight_dict = dict(enumerate(class_weights))

# 모델 학습 시 class_weight 파라미터에 가중치 딕셔너리 전달
history = model.fit(train_input, train_target, epochs=400, batch_size=32, class_weight=class_weight_dict, validation_data=(test_input, test_target))
# Out:
# Epoch 1/400
# 19/19 [==============================] - 1s 17ms/step - loss: 1.7436 - accuracy: 0.2086 - val_loss: 1.5892 - val_accuracy: 0.3056
# Epoch 2/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5853 - accuracy: 0.2219 - val_loss: 1.4797 - val_accuracy: 0.3333
# Epoch 3/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5561 - accuracy: 0.2864 - val_loss: 1.3952 - val_accuracy: 0.4167
# Epoch 4/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5192 - accuracy: 0.2285 - val_loss: 1.5322 - val_accuracy: 0.2500
# Epoch 5/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4515 - accuracy: 0.2732 - val_loss: 1.3216 - val_accuracy: 0.4444
# Epoch 6/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4352 - accuracy: 0.2649 - val_loss: 1.3065 - val_accuracy: 0.3611
# Epoch 7/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3673 - accuracy: 0.2930 - val_loss: 1.1958 - val_accuracy: 0.3611
# Epoch 8/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3237 - accuracy: 0.3146 - val_loss: 1.3021 - val_accuracy: 0.4167
# Epoch 9/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2691 - accuracy: 0.3377 - val_loss: 1.2649 - val_accuracy: 0.3333
# Epoch 10/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2776 - accuracy: 0.3030 - val_loss: 1.1687 - val_accuracy: 0.3889
# Epoch 11/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2304 - accuracy: 0.4123 - val_loss: 1.2359 - val_accuracy: 0.3611
# Epoch 12/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2712 - accuracy: 0.3526 - val_loss: 1.2099 - val_accuracy: 0.3056
# Epoch 13/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2505 - accuracy: 0.3543 - val_loss: 1.3399 - val_accuracy: 0.3889
# Epoch 14/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3102 - accuracy: 0.3444 - val_loss: 1.2228 - val_accuracy: 0.3056
# Epoch 15/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2634 - accuracy: 0.3791 - val_loss: 1.2724 - val_accuracy: 0.4722
# Epoch 16/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1883 - accuracy: 0.3775 - val_loss: 1.2592 - val_accuracy: 0.4444
# Epoch 17/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1400 - accuracy: 0.4073 - val_loss: 1.1563 - val_accuracy: 0.4167
# Epoch 18/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1823 - accuracy: 0.4073 - val_loss: 1.1212 - val_accuracy: 0.5278
# Epoch 19/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2031 - accuracy: 0.3924 - val_loss: 1.1412 - val_accuracy: 0.3611
# Epoch 20/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1508 - accuracy: 0.4156 - val_loss: 1.1538 - val_accuracy: 0.3611
# Epoch 21/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1352 - accuracy: 0.4553 - val_loss: 1.1432 - val_accuracy: 0.3889
# Epoch 22/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1375 - accuracy: 0.4255 - val_loss: 1.1637 - val_accuracy: 0.3889
# Epoch 23/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0780 - accuracy: 0.4553 - val_loss: 1.1116 - val_accuracy: 0.4167
# Epoch 24/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1342 - accuracy: 0.4603 - val_loss: 1.1852 - val_accuracy: 0.4444
# Epoch 25/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0723 - accuracy: 0.4752 - val_loss: 1.1405 - val_accuracy: 0.4722
# Epoch 26/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0348 - accuracy: 0.5066 - val_loss: 1.1540 - val_accuracy: 0.4167
# Epoch 27/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0496 - accuracy: 0.4884 - val_loss: 1.1369 - val_accuracy: 0.4444
# Epoch 28/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0344 - accuracy: 0.4950 - val_loss: 1.1589 - val_accuracy: 0.5278
# Epoch 29/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0245 - accuracy: 0.5215 - val_loss: 1.5011 - val_accuracy: 0.5556
# Epoch 30/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0028 - accuracy: 0.5414 - val_loss: 1.2353 - val_accuracy: 0.4167
# Epoch 31/400
# 19/19 [==============================] - 0s 4ms/step - loss: 1.0231 - accuracy: 0.5248 - val_loss: 1.2829 - val_accuracy: 0.5000
# Epoch 32/400
# 19/19 [==============================] - 0s 10ms/step - loss: 1.0242 - accuracy: 0.4834 - val_loss: 1.2139 - val_accuracy: 0.4722
# Epoch 33/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9237 - accuracy: 0.5579 - val_loss: 1.2930 - val_accuracy: 0.4444
# Epoch 34/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.9600 - accuracy: 0.5447 - val_loss: 1.2959 - val_accuracy: 0.4722
# Epoch 35/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9966 - accuracy: 0.5166 - val_loss: 1.1694 - val_accuracy: 0.4444
# Epoch 36/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9889 - accuracy: 0.5149 - val_loss: 1.2300 - val_accuracy: 0.4167
# Epoch 37/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9352 - accuracy: 0.5480 - val_loss: 1.1665 - val_accuracy: 0.3611
# Epoch 38/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8823 - accuracy: 0.5745 - val_loss: 1.2830 - val_accuracy: 0.4167
# Epoch 39/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8721 - accuracy: 0.5861 - val_loss: 1.3842 - val_accuracy: 0.3611
# Epoch 40/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.9886 - accuracy: 0.5513 - val_loss: 1.2989 - val_accuracy: 0.3611
# Epoch 41/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.9911 - accuracy: 0.5199 - val_loss: 1.3568 - val_accuracy: 0.3333
# Epoch 42/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.9364 - accuracy: 0.5447 - val_loss: 1.3991 - val_accuracy: 0.3333
# Epoch 43/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8744 - accuracy: 0.6126 - val_loss: 1.3776 - val_accuracy: 0.3889
# Epoch 44/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8236 - accuracy: 0.6010 - val_loss: 1.3488 - val_accuracy: 0.4444
# Epoch 45/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7814 - accuracy: 0.6175 - val_loss: 1.2528 - val_accuracy: 0.4444
# Epoch 46/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8401 - accuracy: 0.6010 - val_loss: 1.2946 - val_accuracy: 0.4444
# Epoch 47/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8481 - accuracy: 0.6026 - val_loss: 1.5098 - val_accuracy: 0.4167
# Epoch 48/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8206 - accuracy: 0.5993 - val_loss: 1.2470 - val_accuracy: 0.5278
# Epoch 49/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8368 - accuracy: 0.5993 - val_loss: 1.3953 - val_accuracy: 0.5278
# Epoch 50/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8665 - accuracy: 0.6076 - val_loss: 1.4051 - val_accuracy: 0.3889
# Epoch 51/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8446 - accuracy: 0.5894 - val_loss: 1.3752 - val_accuracy: 0.4722
# Epoch 52/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7979 - accuracy: 0.6209 - val_loss: 1.6234 - val_accuracy: 0.3333
# Epoch 53/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7575 - accuracy: 0.6275 - val_loss: 1.4032 - val_accuracy: 0.4444
# Epoch 54/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7008 - accuracy: 0.6871 - val_loss: 1.5594 - val_accuracy: 0.4167
# Epoch 55/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6595 - accuracy: 0.6904 - val_loss: 1.7279 - val_accuracy: 0.3611
# Epoch 56/400
# 19/19 [==============================] - 0s 9ms/step - loss: 0.6823 - accuracy: 0.6954 - val_loss: 1.6800 - val_accuracy: 0.4167
# Epoch 57/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7453 - accuracy: 0.6606 - val_loss: 1.9184 - val_accuracy: 0.3611
# Epoch 58/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6923 - accuracy: 0.6722 - val_loss: 1.6709 - val_accuracy: 0.4167
# Epoch 59/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6307 - accuracy: 0.7053 - val_loss: 2.1157 - val_accuracy: 0.4167
# Epoch 60/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7050 - accuracy: 0.6970 - val_loss: 1.9249 - val_accuracy: 0.4167
# Epoch 61/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6628 - accuracy: 0.6887 - val_loss: 1.7380 - val_accuracy: 0.4444
# Epoch 62/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6126 - accuracy: 0.7119 - val_loss: 2.1718 - val_accuracy: 0.4167
# Epoch 63/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6658 - accuracy: 0.6689 - val_loss: 2.1667 - val_accuracy: 0.3333
# Epoch 64/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7026 - accuracy: 0.6887 - val_loss: 1.9789 - val_accuracy: 0.4444
# Epoch 65/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7113 - accuracy: 0.6821 - val_loss: 1.6237 - val_accuracy: 0.3611
# Epoch 66/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8347 - accuracy: 0.6440 - val_loss: 1.8559 - val_accuracy: 0.2778
# Epoch 67/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7787 - accuracy: 0.6424 - val_loss: 1.7293 - val_accuracy: 0.4167
# Epoch 68/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7552 - accuracy: 0.6672 - val_loss: 1.5929 - val_accuracy: 0.3611
# Epoch 69/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6825 - accuracy: 0.6821 - val_loss: 1.5123 - val_accuracy: 0.4444
# Epoch 70/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6008 - accuracy: 0.7252 - val_loss: 1.6944 - val_accuracy: 0.4444
# Epoch 71/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5248 - accuracy: 0.7550 - val_loss: 1.6933 - val_accuracy: 0.3333
# Epoch 72/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4854 - accuracy: 0.7864 - val_loss: 1.9855 - val_accuracy: 0.4722
# Epoch 73/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4717 - accuracy: 0.7699 - val_loss: 1.7436 - val_accuracy: 0.5000
# Epoch 74/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4813 - accuracy: 0.7748 - val_loss: 2.5462 - val_accuracy: 0.3889
# Epoch 75/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6040 - accuracy: 0.7351 - val_loss: 2.0033 - val_accuracy: 0.3333
# Epoch 76/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6412 - accuracy: 0.6937 - val_loss: 1.9089 - val_accuracy: 0.3889
# Epoch 77/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6087 - accuracy: 0.7185 - val_loss: 1.7660 - val_accuracy: 0.4167
# Epoch 78/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6211 - accuracy: 0.7334 - val_loss: 1.9028 - val_accuracy: 0.3611
# Epoch 79/400
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6027 - accuracy: 0.7119 - val_loss: 1.9824 - val_accuracy: 0.4444
# Epoch 80/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5506 - accuracy: 0.7334 - val_loss: 1.8304 - val_accuracy: 0.4167
# Epoch 81/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4758 - accuracy: 0.7848 - val_loss: 2.0797 - val_accuracy: 0.4722
# Epoch 82/400
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4238 - accuracy: 0.8162 - val_loss: 2.0468 - val_accuracy: 0.4722
# Epoch 83/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3895 - accuracy: 0.8344 - val_loss: 1.9716 - val_accuracy: 0.3889
# Epoch 84/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4927 - accuracy: 0.7897 - val_loss: 2.0809 - val_accuracy: 0.4444
# Epoch 85/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5344 - accuracy: 0.7616 - val_loss: 1.7711 - val_accuracy: 0.3889
# Epoch 86/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4824 - accuracy: 0.7732 - val_loss: 1.9352 - val_accuracy: 0.4444
# Epoch 87/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4933 - accuracy: 0.7699 - val_loss: 1.8094 - val_accuracy: 0.5000
# Epoch 88/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4725 - accuracy: 0.7881 - val_loss: 2.3429 - val_accuracy: 0.4167
# Epoch 89/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4717 - accuracy: 0.7765 - val_loss: 2.0022 - val_accuracy: 0.3889
# Epoch 90/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4858 - accuracy: 0.8013 - val_loss: 1.9023 - val_accuracy: 0.4167
# Epoch 91/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4316 - accuracy: 0.8030 - val_loss: 2.5728 - val_accuracy: 0.3611
# Epoch 92/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3943 - accuracy: 0.8046 - val_loss: 2.4250 - val_accuracy: 0.3611
# Epoch 93/400
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3446 - accuracy: 0.8295 - val_loss: 3.0294 - val_accuracy: 0.3611
# Epoch 94/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3854 - accuracy: 0.8162 - val_loss: 2.3916 - val_accuracy: 0.3889
# Epoch 95/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3372 - accuracy: 0.8394 - val_loss: 2.2791 - val_accuracy: 0.4722
# Epoch 96/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2750 - accuracy: 0.8725 - val_loss: 2.5768 - val_accuracy: 0.4167
# Epoch 97/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3166 - accuracy: 0.8692 - val_loss: 2.8412 - val_accuracy: 0.2778
# Epoch 98/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4433 - accuracy: 0.8311 - val_loss: 2.1611 - val_accuracy: 0.3889
# Epoch 99/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4441 - accuracy: 0.7864 - val_loss: 2.3294 - val_accuracy: 0.4444
# Epoch 100/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4208 - accuracy: 0.8162 - val_loss: 2.3207 - val_accuracy: 0.5000
# Epoch 101/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3683 - accuracy: 0.8162 - val_loss: 3.0654 - val_accuracy: 0.2778
# Epoch 102/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3044 - accuracy: 0.8593 - val_loss: 3.4185 - val_accuracy: 0.3611
# Epoch 103/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3103 - accuracy: 0.8493 - val_loss: 2.6712 - val_accuracy: 0.4444
# Epoch 104/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2739 - accuracy: 0.8907 - val_loss: 3.3902 - val_accuracy: 0.3056
# Epoch 105/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3277 - accuracy: 0.8642 - val_loss: 4.6698 - val_accuracy: 0.4167
# Epoch 106/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7147 - accuracy: 0.7897 - val_loss: 1.7447 - val_accuracy: 0.5000
# Epoch 107/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5146 - accuracy: 0.7599 - val_loss: 2.0644 - val_accuracy: 0.4167
# Epoch 108/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4178 - accuracy: 0.8129 - val_loss: 1.8525 - val_accuracy: 0.4722
# Epoch 109/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3672 - accuracy: 0.8278 - val_loss: 1.9503 - val_accuracy: 0.5000
# Epoch 110/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2790 - accuracy: 0.8560 - val_loss: 2.2734 - val_accuracy: 0.4167
# Epoch 111/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3214 - accuracy: 0.8791 - val_loss: 2.5511 - val_accuracy: 0.3611
# Epoch 112/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2669 - accuracy: 0.8940 - val_loss: 2.3525 - val_accuracy: 0.5278
# Epoch 113/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2361 - accuracy: 0.8907 - val_loss: 2.7614 - val_accuracy: 0.3889
# Epoch 114/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2577 - accuracy: 0.8874 - val_loss: 2.7338 - val_accuracy: 0.4722
# Epoch 115/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2579 - accuracy: 0.8791 - val_loss: 2.7198 - val_accuracy: 0.4444
# Epoch 116/400
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3589 - accuracy: 0.8576 - val_loss: 3.0412 - val_accuracy: 0.3333
# Epoch 117/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4154 - accuracy: 0.8427 - val_loss: 2.1575 - val_accuracy: 0.3889
# Epoch 118/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3231 - accuracy: 0.8609 - val_loss: 2.5035 - val_accuracy: 0.3611
# Epoch 119/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2654 - accuracy: 0.8808 - val_loss: 3.0812 - val_accuracy: 0.4722
# Epoch 120/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2615 - accuracy: 0.8675 - val_loss: 3.1739 - val_accuracy: 0.3889
# Epoch 121/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.8775 - val_loss: 3.1233 - val_accuracy: 0.4444
# Epoch 122/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2888 - accuracy: 0.8841 - val_loss: 3.2088 - val_accuracy: 0.3611
# Epoch 123/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3000 - accuracy: 0.8692 - val_loss: 3.1048 - val_accuracy: 0.3889
# Epoch 124/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2848 - accuracy: 0.8659 - val_loss: 3.4024 - val_accuracy: 0.3889
# Epoch 125/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3219 - accuracy: 0.8692 - val_loss: 3.0120 - val_accuracy: 0.4167
# Epoch 126/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2494 - accuracy: 0.8990 - val_loss: 3.1693 - val_accuracy: 0.3889
# Epoch 127/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2233 - accuracy: 0.8974 - val_loss: 2.8930 - val_accuracy: 0.3333
# Epoch 128/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2122 - accuracy: 0.8858 - val_loss: 3.7034 - val_accuracy: 0.3611
# Epoch 129/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1968 - accuracy: 0.9023 - val_loss: 2.9351 - val_accuracy: 0.3611
# Epoch 130/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1851 - accuracy: 0.9272 - val_loss: 3.4043 - val_accuracy: 0.3056
# Epoch 131/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1801 - accuracy: 0.9272 - val_loss: 3.6602 - val_accuracy: 0.3889
# Epoch 132/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2228 - accuracy: 0.8957 - val_loss: 3.2945 - val_accuracy: 0.4167
# Epoch 133/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2730 - accuracy: 0.8858 - val_loss: 3.8479 - val_accuracy: 0.3611
# Epoch 134/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4946 - accuracy: 0.8361 - val_loss: 3.4714 - val_accuracy: 0.3333
# Epoch 135/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6250 - accuracy: 0.7930 - val_loss: 3.8978 - val_accuracy: 0.3889
# Epoch 136/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4424 - accuracy: 0.8146 - val_loss: 2.5981 - val_accuracy: 0.3611
# Epoch 137/400
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3220 - accuracy: 0.8692 - val_loss: 2.3317 - val_accuracy: 0.3889
# Epoch 138/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2256 - accuracy: 0.9007 - val_loss: 2.4371 - val_accuracy: 0.4722
# Epoch 139/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1595 - accuracy: 0.9255 - val_loss: 2.7903 - val_accuracy: 0.4444
# Epoch 140/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1511 - accuracy: 0.9305 - val_loss: 3.1231 - val_accuracy: 0.4167
# Epoch 141/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1604 - accuracy: 0.9288 - val_loss: 3.3218 - val_accuracy: 0.4167
# Epoch 142/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1852 - accuracy: 0.9238 - val_loss: 3.2166 - val_accuracy: 0.2778
# Epoch 143/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2286 - accuracy: 0.9007 - val_loss: 3.3144 - val_accuracy: 0.4722
# Epoch 144/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2138 - accuracy: 0.9007 - val_loss: 3.6800 - val_accuracy: 0.4167
# Epoch 145/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3084 - accuracy: 0.8709 - val_loss: 2.7547 - val_accuracy: 0.4722
# Epoch 146/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3215 - accuracy: 0.8725 - val_loss: 3.1557 - val_accuracy: 0.3611
# Epoch 147/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2896 - accuracy: 0.8957 - val_loss: 3.9193 - val_accuracy: 0.3333
# Epoch 148/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3343 - accuracy: 0.8593 - val_loss: 3.3038 - val_accuracy: 0.3333
# Epoch 149/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3382 - accuracy: 0.8493 - val_loss: 3.2203 - val_accuracy: 0.3889
# Epoch 150/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3535 - accuracy: 0.8493 - val_loss: 3.5663 - val_accuracy: 0.3889
# Epoch 151/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2204 - accuracy: 0.8974 - val_loss: 3.0873 - val_accuracy: 0.3056
# Epoch 152/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1640 - accuracy: 0.9288 - val_loss: 3.3508 - val_accuracy: 0.3889
# Epoch 153/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1322 - accuracy: 0.9371 - val_loss: 3.2225 - val_accuracy: 0.4722
# Epoch 154/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1006 - accuracy: 0.9603 - val_loss: 3.6910 - val_accuracy: 0.3889
# Epoch 155/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1091 - accuracy: 0.9586 - val_loss: 3.2998 - val_accuracy: 0.4444
# Epoch 156/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1365 - accuracy: 0.9454 - val_loss: 3.3135 - val_accuracy: 0.4167
# Epoch 157/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0985 - accuracy: 0.9619 - val_loss: 3.2098 - val_accuracy: 0.4444
# Epoch 158/400
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1072 - accuracy: 0.9470 - val_loss: 3.5157 - val_accuracy: 0.3889
# Epoch 159/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0879 - accuracy: 0.9603 - val_loss: 3.9417 - val_accuracy: 0.4167
# Epoch 160/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0763 - accuracy: 0.9669 - val_loss: 4.1255 - val_accuracy: 0.3889
# Epoch 161/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0548 - accuracy: 0.9818 - val_loss: 4.4293 - val_accuracy: 0.3611
# Epoch 162/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0803 - accuracy: 0.9735 - val_loss: 4.0402 - val_accuracy: 0.3889
# Epoch 163/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9570 - val_loss: 4.4764 - val_accuracy: 0.3889
# Epoch 164/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0701 - accuracy: 0.9652 - val_loss: 4.6781 - val_accuracy: 0.3611
# Epoch 165/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0494 - accuracy: 0.9851 - val_loss: 4.6167 - val_accuracy: 0.3611
# Epoch 166/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9801 - val_loss: 4.9867 - val_accuracy: 0.3333
# Epoch 167/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0477 - accuracy: 0.9818 - val_loss: 4.8648 - val_accuracy: 0.3056
# Epoch 168/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9719 - val_loss: 4.7173 - val_accuracy: 0.4167
# Epoch 169/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0801 - accuracy: 0.9685 - val_loss: 4.8921 - val_accuracy: 0.3611
# Epoch 170/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1142 - accuracy: 0.9536 - val_loss: 4.9119 - val_accuracy: 0.3333
# Epoch 171/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4918 - accuracy: 0.8543 - val_loss: 4.4266 - val_accuracy: 0.4722
# Epoch 172/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9642 - accuracy: 0.7202 - val_loss: 3.4709 - val_accuracy: 0.3333
# Epoch 173/400
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8530 - accuracy: 0.6788 - val_loss: 2.4171 - val_accuracy: 0.3889
# Epoch 174/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6458 - accuracy: 0.7550 - val_loss: 2.0240 - val_accuracy: 0.3056
# Epoch 175/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4329 - accuracy: 0.7947 - val_loss: 1.8968 - val_accuracy: 0.4167
# Epoch 176/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2789 - accuracy: 0.8924 - val_loss: 2.6639 - val_accuracy: 0.3611
# Epoch 177/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2935 - accuracy: 0.8675 - val_loss: 2.8100 - val_accuracy: 0.2778
# Epoch 178/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2082 - accuracy: 0.9139 - val_loss: 2.9443 - val_accuracy: 0.3611
# Epoch 179/400
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1724 - accuracy: 0.9454 - val_loss: 4.0436 - val_accuracy: 0.2500
# Epoch 180/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2070 - accuracy: 0.9089 - val_loss: 3.7335 - val_accuracy: 0.3056
# Epoch 181/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1354 - accuracy: 0.9387 - val_loss: 3.5764 - val_accuracy: 0.4167
# Epoch 182/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.9487 - val_loss: 3.8868 - val_accuracy: 0.3889
# Epoch 183/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1162 - accuracy: 0.9619 - val_loss: 4.2016 - val_accuracy: 0.3056
# Epoch 184/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1732 - accuracy: 0.9371 - val_loss: 3.7639 - val_accuracy: 0.4722
# Epoch 185/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2119 - accuracy: 0.9040 - val_loss: 3.6297 - val_accuracy: 0.4167
# Epoch 186/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2179 - accuracy: 0.9255 - val_loss: 3.7261 - val_accuracy: 0.4167
# Epoch 187/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1751 - accuracy: 0.9139 - val_loss: 3.2997 - val_accuracy: 0.5556
# Epoch 188/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1946 - accuracy: 0.9123 - val_loss: 3.9743 - val_accuracy: 0.3056
# Epoch 189/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1797 - accuracy: 0.9222 - val_loss: 3.3619 - val_accuracy: 0.4444
# Epoch 190/400
# 19/19 [==============================] - 0s 7ms/step - loss: 0.2608 - accuracy: 0.9056 - val_loss: 3.4699 - val_accuracy: 0.4722
# Epoch 191/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2992 - accuracy: 0.8841 - val_loss: 3.5092 - val_accuracy: 0.3333
# Epoch 192/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2925 - accuracy: 0.8709 - val_loss: 3.5212 - val_accuracy: 0.3611
# Epoch 193/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4497 - accuracy: 0.8493 - val_loss: 3.7054 - val_accuracy: 0.3611
# Epoch 194/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4761 - accuracy: 0.8179 - val_loss: 3.6430 - val_accuracy: 0.3889
# Epoch 195/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2642 - accuracy: 0.8907 - val_loss: 3.7494 - val_accuracy: 0.3889
# Epoch 196/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2272 - accuracy: 0.9172 - val_loss: 3.4386 - val_accuracy: 0.3889
# Epoch 197/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1511 - accuracy: 0.9454 - val_loss: 3.5821 - val_accuracy: 0.3889
# Epoch 198/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1411 - accuracy: 0.9421 - val_loss: 4.0675 - val_accuracy: 0.3889
# Epoch 199/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0983 - accuracy: 0.9636 - val_loss: 3.6155 - val_accuracy: 0.4444
# Epoch 200/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1664 - accuracy: 0.9371 - val_loss: 4.5484 - val_accuracy: 0.3611
# Epoch 201/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1998 - accuracy: 0.9354 - val_loss: 4.6078 - val_accuracy: 0.3889
# Epoch 202/400
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2332 - accuracy: 0.9073 - val_loss: 4.0637 - val_accuracy: 0.3889
# Epoch 203/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2516 - accuracy: 0.9040 - val_loss: 3.7928 - val_accuracy: 0.4167
# Epoch 204/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2489 - accuracy: 0.9222 - val_loss: 3.9538 - val_accuracy: 0.2778
# Epoch 205/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1528 - accuracy: 0.9470 - val_loss: 3.8786 - val_accuracy: 0.3333
# Epoch 206/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1210 - accuracy: 0.9404 - val_loss: 3.5904 - val_accuracy: 0.4444
# Epoch 207/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1545 - accuracy: 0.9503 - val_loss: 3.5545 - val_accuracy: 0.3889
# Epoch 208/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1649 - accuracy: 0.9371 - val_loss: 3.7832 - val_accuracy: 0.4444
# Epoch 209/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1377 - accuracy: 0.9371 - val_loss: 3.7986 - val_accuracy: 0.4167
# Epoch 210/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0646 - accuracy: 0.9719 - val_loss: 4.1959 - val_accuracy: 0.3611
# Epoch 211/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0604 - accuracy: 0.9735 - val_loss: 4.1601 - val_accuracy: 0.3889
# Epoch 212/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0479 - accuracy: 0.9785 - val_loss: 4.2370 - val_accuracy: 0.4167
# Epoch 213/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0468 - accuracy: 0.9868 - val_loss: 4.7756 - val_accuracy: 0.4167
# Epoch 214/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0305 - accuracy: 0.9884 - val_loss: 4.7600 - val_accuracy: 0.3889
# Epoch 215/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9884 - val_loss: 4.3923 - val_accuracy: 0.3889
# Epoch 216/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0259 - accuracy: 0.9901 - val_loss: 4.5041 - val_accuracy: 0.3611
# Epoch 217/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0229 - accuracy: 0.9884 - val_loss: 4.4546 - val_accuracy: 0.4167
# Epoch 218/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9934 - val_loss: 4.5033 - val_accuracy: 0.3889
# Epoch 219/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0210 - accuracy: 0.9934 - val_loss: 4.5627 - val_accuracy: 0.4167
# Epoch 220/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 0.9917 - val_loss: 4.6756 - val_accuracy: 0.3889
# Epoch 221/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9917 - val_loss: 4.6015 - val_accuracy: 0.4167
# Epoch 222/400
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0188 - accuracy: 0.9917 - val_loss: 4.7176 - val_accuracy: 0.3889
# Epoch 223/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9917 - val_loss: 4.8967 - val_accuracy: 0.4167
# Epoch 224/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0220 - accuracy: 0.9901 - val_loss: 4.8551 - val_accuracy: 0.3611
# Epoch 225/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0230 - accuracy: 0.9901 - val_loss: 5.0564 - val_accuracy: 0.4167
# Epoch 226/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9917 - val_loss: 5.0504 - val_accuracy: 0.4444
# Epoch 227/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0327 - accuracy: 0.9884 - val_loss: 4.9384 - val_accuracy: 0.3889
# Epoch 228/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 0.9818 - val_loss: 5.3667 - val_accuracy: 0.4167
# Epoch 229/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1194 - accuracy: 0.9487 - val_loss: 4.9190 - val_accuracy: 0.5000
# Epoch 230/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4454 - accuracy: 0.8742 - val_loss: 5.6766 - val_accuracy: 0.3889
# Epoch 231/400
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0046 - accuracy: 0.7219 - val_loss: 3.4321 - val_accuracy: 0.3056
# Epoch 232/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7090 - accuracy: 0.7417 - val_loss: 2.4606 - val_accuracy: 0.4167
# Epoch 233/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5137 - accuracy: 0.7914 - val_loss: 2.6313 - val_accuracy: 0.3889
# Epoch 234/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3962 - accuracy: 0.8427 - val_loss: 2.4334 - val_accuracy: 0.3056
# Epoch 235/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2783 - accuracy: 0.8874 - val_loss: 2.9813 - val_accuracy: 0.3889
# Epoch 236/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1566 - accuracy: 0.9255 - val_loss: 3.0316 - val_accuracy: 0.4167
# Epoch 237/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1506 - accuracy: 0.9404 - val_loss: 3.3897 - val_accuracy: 0.3611
# Epoch 238/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1264 - accuracy: 0.9404 - val_loss: 4.2360 - val_accuracy: 0.3333
# Epoch 239/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0979 - accuracy: 0.9487 - val_loss: 4.3334 - val_accuracy: 0.3333
# Epoch 240/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0776 - accuracy: 0.9586 - val_loss: 4.1411 - val_accuracy: 0.3889
# Epoch 241/400
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0614 - accuracy: 0.9768 - val_loss: 4.1985 - val_accuracy: 0.3611
# Epoch 242/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0639 - accuracy: 0.9719 - val_loss: 4.8082 - val_accuracy: 0.3611
# Epoch 243/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0627 - accuracy: 0.9801 - val_loss: 4.7623 - val_accuracy: 0.3611
# Epoch 244/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0448 - accuracy: 0.9818 - val_loss: 4.7175 - val_accuracy: 0.4167
# Epoch 245/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0338 - accuracy: 0.9868 - val_loss: 4.5622 - val_accuracy: 0.4444
# Epoch 246/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 0.9884 - val_loss: 4.8459 - val_accuracy: 0.3889
# Epoch 247/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0294 - accuracy: 0.9884 - val_loss: 4.8537 - val_accuracy: 0.4444
# Epoch 248/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0307 - accuracy: 0.9884 - val_loss: 4.6947 - val_accuracy: 0.3889
# Epoch 249/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0240 - accuracy: 0.9901 - val_loss: 4.9188 - val_accuracy: 0.4444
# Epoch 250/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.9884 - val_loss: 5.1931 - val_accuracy: 0.3889
# Epoch 251/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0226 - accuracy: 0.9868 - val_loss: 5.0722 - val_accuracy: 0.4444
# Epoch 252/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 0.9884 - val_loss: 5.4052 - val_accuracy: 0.3889
# Epoch 253/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0285 - accuracy: 0.9868 - val_loss: 5.3712 - val_accuracy: 0.4167
# Epoch 254/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9917 - val_loss: 5.4769 - val_accuracy: 0.4167
# Epoch 255/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0177 - accuracy: 0.9917 - val_loss: 5.4807 - val_accuracy: 0.3889
# Epoch 256/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.9868 - val_loss: 5.6098 - val_accuracy: 0.4167
# Epoch 257/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0204 - accuracy: 0.9884 - val_loss: 5.7068 - val_accuracy: 0.4167
# Epoch 258/400
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0157 - accuracy: 0.9917 - val_loss: 5.7093 - val_accuracy: 0.4167
# Epoch 259/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9917 - val_loss: 5.8341 - val_accuracy: 0.4167
# Epoch 260/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9917 - val_loss: 5.9306 - val_accuracy: 0.4167
# Epoch 261/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0150 - accuracy: 0.9917 - val_loss: 6.0047 - val_accuracy: 0.4167
# Epoch 262/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9884 - val_loss: 5.9562 - val_accuracy: 0.3889
# Epoch 263/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0307 - accuracy: 0.9868 - val_loss: 6.3672 - val_accuracy: 0.3889
# Epoch 264/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3305 - accuracy: 0.9354 - val_loss: 6.2544 - val_accuracy: 0.2500
# Epoch 265/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8788 - accuracy: 0.7649 - val_loss: 3.8486 - val_accuracy: 0.3333
# Epoch 266/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7158 - accuracy: 0.7384 - val_loss: 2.2041 - val_accuracy: 0.3889
# Epoch 267/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4791 - accuracy: 0.8096 - val_loss: 2.8216 - val_accuracy: 0.4444
# Epoch 268/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3399 - accuracy: 0.8593 - val_loss: 2.7590 - val_accuracy: 0.3611
# Epoch 269/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2953 - accuracy: 0.8642 - val_loss: 3.3084 - val_accuracy: 0.3889
# Epoch 270/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2181 - accuracy: 0.9007 - val_loss: 3.3629 - val_accuracy: 0.4444
# Epoch 271/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1615 - accuracy: 0.9371 - val_loss: 3.9342 - val_accuracy: 0.3056
# Epoch 272/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1197 - accuracy: 0.9454 - val_loss: 3.8054 - val_accuracy: 0.4722
# Epoch 273/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0948 - accuracy: 0.9603 - val_loss: 4.1306 - val_accuracy: 0.3889
# Epoch 274/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0696 - accuracy: 0.9752 - val_loss: 4.2192 - val_accuracy: 0.3889
# Epoch 275/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0712 - accuracy: 0.9801 - val_loss: 4.1601 - val_accuracy: 0.4167
# Epoch 276/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0660 - accuracy: 0.9785 - val_loss: 4.7602 - val_accuracy: 0.4167
# Epoch 277/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0477 - accuracy: 0.9818 - val_loss: 5.1306 - val_accuracy: 0.3889
# Epoch 278/400
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0323 - accuracy: 0.9851 - val_loss: 4.8305 - val_accuracy: 0.4444
# Epoch 279/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0302 - accuracy: 0.9868 - val_loss: 5.2924 - val_accuracy: 0.4444
# Epoch 280/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9934 - val_loss: 5.5304 - val_accuracy: 0.4167
# Epoch 281/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9917 - val_loss: 5.1925 - val_accuracy: 0.5000
# Epoch 282/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0351 - accuracy: 0.9868 - val_loss: 5.5127 - val_accuracy: 0.4444
# Epoch 283/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0326 - accuracy: 0.9868 - val_loss: 5.6474 - val_accuracy: 0.3889
# Epoch 284/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9884 - val_loss: 5.5040 - val_accuracy: 0.3333
# Epoch 285/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 0.9934 - val_loss: 5.6418 - val_accuracy: 0.4167
# Epoch 286/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0247 - accuracy: 0.9917 - val_loss: 5.5753 - val_accuracy: 0.4444
# Epoch 287/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9917 - val_loss: 5.6526 - val_accuracy: 0.4167
# Epoch 288/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9901 - val_loss: 5.7984 - val_accuracy: 0.3889
# Epoch 289/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9901 - val_loss: 6.0043 - val_accuracy: 0.3889
# Epoch 290/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9917 - val_loss: 5.9700 - val_accuracy: 0.3889
# Epoch 291/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 0.9917 - val_loss: 5.9680 - val_accuracy: 0.3889
# Epoch 292/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 0.9901 - val_loss: 6.1169 - val_accuracy: 0.3889
# Epoch 293/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 0.9884 - val_loss: 6.1719 - val_accuracy: 0.3889
# Epoch 294/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9934 - val_loss: 6.1427 - val_accuracy: 0.3889
# Epoch 295/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9917 - val_loss: 6.3425 - val_accuracy: 0.3889
# Epoch 296/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.9901 - val_loss: 6.4121 - val_accuracy: 0.3889
# Epoch 297/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9901 - val_loss: 6.5606 - val_accuracy: 0.4167
# Epoch 298/400
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0133 - accuracy: 0.9934 - val_loss: 6.5923 - val_accuracy: 0.3889
# Epoch 299/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9934 - val_loss: 6.5080 - val_accuracy: 0.3889
# Epoch 300/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9917 - val_loss: 6.6501 - val_accuracy: 0.4167
# Epoch 301/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9934 - val_loss: 6.6981 - val_accuracy: 0.4167
# Epoch 302/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 0.9934 - val_loss: 6.7338 - val_accuracy: 0.4167
# Epoch 303/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 0.9950 - val_loss: 6.8041 - val_accuracy: 0.4167
# Epoch 304/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 0.9950 - val_loss: 6.9077 - val_accuracy: 0.4167
# Epoch 305/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 0.9934 - val_loss: 6.9416 - val_accuracy: 0.3889
# Epoch 306/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 0.9934 - val_loss: 6.9435 - val_accuracy: 0.4167
# Epoch 307/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.9917 - val_loss: 7.0246 - val_accuracy: 0.3889
# Epoch 308/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9934 - val_loss: 7.1549 - val_accuracy: 0.4444
# Epoch 309/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9934 - val_loss: 6.8360 - val_accuracy: 0.3889
# Epoch 310/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 0.9901 - val_loss: 7.4593 - val_accuracy: 0.4444
# Epoch 311/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0560 - accuracy: 0.9818 - val_loss: 6.6071 - val_accuracy: 0.4167
# Epoch 312/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1650 - accuracy: 0.9536 - val_loss: 6.5600 - val_accuracy: 0.4444
# Epoch 313/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5449 - accuracy: 0.8576 - val_loss: 4.6062 - val_accuracy: 0.4722
# Epoch 314/400
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0374 - accuracy: 0.6904 - val_loss: 3.1916 - val_accuracy: 0.4167
# Epoch 315/400
# 19/19 [==============================] - 0s 10ms/step - loss: 0.9337 - accuracy: 0.6358 - val_loss: 2.4893 - val_accuracy: 0.3611
# Epoch 316/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7972 - accuracy: 0.6589 - val_loss: 2.6508 - val_accuracy: 0.3889
# Epoch 317/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6332 - accuracy: 0.7235 - val_loss: 2.5018 - val_accuracy: 0.3056
# Epoch 318/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4335 - accuracy: 0.8295 - val_loss: 2.6461 - val_accuracy: 0.3889
# Epoch 319/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3327 - accuracy: 0.8526 - val_loss: 3.2329 - val_accuracy: 0.3889
# Epoch 320/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2937 - accuracy: 0.8858 - val_loss: 3.7644 - val_accuracy: 0.3611
# Epoch 321/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2668 - accuracy: 0.8841 - val_loss: 3.3976 - val_accuracy: 0.3889
# Epoch 322/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2721 - accuracy: 0.8791 - val_loss: 3.6742 - val_accuracy: 0.3889
# Epoch 323/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2380 - accuracy: 0.8974 - val_loss: 4.1598 - val_accuracy: 0.3333
# Epoch 324/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2705 - accuracy: 0.8775 - val_loss: 4.2627 - val_accuracy: 0.3611
# Epoch 325/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2886 - accuracy: 0.8874 - val_loss: 3.5212 - val_accuracy: 0.3611
# Epoch 326/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1948 - accuracy: 0.9156 - val_loss: 4.1949 - val_accuracy: 0.2778
# Epoch 327/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1303 - accuracy: 0.9404 - val_loss: 4.5856 - val_accuracy: 0.4167
# Epoch 328/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0860 - accuracy: 0.9719 - val_loss: 4.8381 - val_accuracy: 0.4444
# Epoch 329/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0574 - accuracy: 0.9818 - val_loss: 5.0187 - val_accuracy: 0.3889
# Epoch 330/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0462 - accuracy: 0.9851 - val_loss: 5.2737 - val_accuracy: 0.4444
# Epoch 331/400
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0316 - accuracy: 0.9868 - val_loss: 5.3532 - val_accuracy: 0.4722
# Epoch 332/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0263 - accuracy: 0.9901 - val_loss: 5.5838 - val_accuracy: 0.4722
# Epoch 333/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9752 - val_loss: 5.4662 - val_accuracy: 0.3333
# Epoch 334/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2988 - accuracy: 0.9023 - val_loss: 4.4928 - val_accuracy: 0.4444
# Epoch 335/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3401 - accuracy: 0.8858 - val_loss: 5.0649 - val_accuracy: 0.3056
# Epoch 336/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2310 - accuracy: 0.9123 - val_loss: 4.3791 - val_accuracy: 0.4167
# Epoch 337/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3967 - accuracy: 0.8477 - val_loss: 4.4346 - val_accuracy: 0.4444
# Epoch 338/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3499 - accuracy: 0.8593 - val_loss: 3.7960 - val_accuracy: 0.3056
# Epoch 339/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2005 - accuracy: 0.9056 - val_loss: 4.1684 - val_accuracy: 0.3889
# Epoch 340/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1484 - accuracy: 0.9404 - val_loss: 4.3826 - val_accuracy: 0.4444
# Epoch 341/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1227 - accuracy: 0.9503 - val_loss: 4.2099 - val_accuracy: 0.5000
# Epoch 342/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0791 - accuracy: 0.9553 - val_loss: 4.6792 - val_accuracy: 0.3611
# Epoch 343/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0962 - accuracy: 0.9669 - val_loss: 5.2742 - val_accuracy: 0.3333
# Epoch 344/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1469 - accuracy: 0.9421 - val_loss: 4.5000 - val_accuracy: 0.3889
# Epoch 345/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1355 - accuracy: 0.9520 - val_loss: 4.6904 - val_accuracy: 0.3611
# Epoch 346/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1284 - accuracy: 0.9487 - val_loss: 4.8749 - val_accuracy: 0.4167
# Epoch 347/400
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1374 - accuracy: 0.9421 - val_loss: 4.5805 - val_accuracy: 0.5000
# Epoch 348/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2120 - accuracy: 0.9238 - val_loss: 4.8943 - val_accuracy: 0.3889
# Epoch 349/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9305 - val_loss: 4.7131 - val_accuracy: 0.3611
# Epoch 350/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0990 - accuracy: 0.9586 - val_loss: 4.5595 - val_accuracy: 0.3889
# Epoch 351/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0672 - accuracy: 0.9702 - val_loss: 4.9062 - val_accuracy: 0.3889
# Epoch 352/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0470 - accuracy: 0.9801 - val_loss: 5.2212 - val_accuracy: 0.3056
# Epoch 353/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0329 - accuracy: 0.9851 - val_loss: 5.2134 - val_accuracy: 0.3333
# Epoch 354/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0338 - accuracy: 0.9868 - val_loss: 5.1735 - val_accuracy: 0.4444
# Epoch 355/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 0.9901 - val_loss: 5.2839 - val_accuracy: 0.4167
# Epoch 356/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0231 - accuracy: 0.9868 - val_loss: 5.5374 - val_accuracy: 0.3889
# Epoch 357/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9917 - val_loss: 5.5258 - val_accuracy: 0.4167
# Epoch 358/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9934 - val_loss: 5.6232 - val_accuracy: 0.4444
# Epoch 359/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9901 - val_loss: 5.8452 - val_accuracy: 0.3889
# Epoch 360/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9917 - val_loss: 5.8405 - val_accuracy: 0.4167
# Epoch 361/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0139 - accuracy: 0.9901 - val_loss: 5.8210 - val_accuracy: 0.3889
# Epoch 362/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9901 - val_loss: 5.9472 - val_accuracy: 0.3611
# Epoch 363/400
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0121 - accuracy: 0.9901 - val_loss: 6.0611 - val_accuracy: 0.4167
# Epoch 364/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 0.9934 - val_loss: 6.1243 - val_accuracy: 0.3611
# Epoch 365/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9901 - val_loss: 6.1440 - val_accuracy: 0.3889
# Epoch 366/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9934 - val_loss: 6.1681 - val_accuracy: 0.3889
# Epoch 367/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 0.9917 - val_loss: 6.3916 - val_accuracy: 0.3333
# Epoch 368/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0493 - accuracy: 0.9901 - val_loss: 6.2093 - val_accuracy: 0.4167
# Epoch 369/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0846 - accuracy: 0.9818 - val_loss: 6.3900 - val_accuracy: 0.3333
# Epoch 370/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1072 - accuracy: 0.9669 - val_loss: 5.6743 - val_accuracy: 0.3611
# Epoch 371/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3479 - accuracy: 0.9056 - val_loss: 5.3900 - val_accuracy: 0.4722
# Epoch 372/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3276 - accuracy: 0.9238 - val_loss: 5.2732 - val_accuracy: 0.4167
# Epoch 373/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2799 - accuracy: 0.8891 - val_loss: 4.0855 - val_accuracy: 0.4167
# Epoch 374/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2956 - accuracy: 0.8841 - val_loss: 4.2031 - val_accuracy: 0.4167
# Epoch 375/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2506 - accuracy: 0.9040 - val_loss: 4.5016 - val_accuracy: 0.3333
# Epoch 376/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3483 - accuracy: 0.8675 - val_loss: 4.2076 - val_accuracy: 0.3333
# Epoch 377/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2173 - accuracy: 0.9040 - val_loss: 3.9396 - val_accuracy: 0.3611
# Epoch 378/400
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1389 - accuracy: 0.9470 - val_loss: 4.6217 - val_accuracy: 0.3056
# Epoch 379/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3122 - accuracy: 0.9189 - val_loss: 4.4241 - val_accuracy: 0.4167
# Epoch 380/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2886 - accuracy: 0.8924 - val_loss: 4.4411 - val_accuracy: 0.2500
# Epoch 381/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1747 - accuracy: 0.9387 - val_loss: 5.0583 - val_accuracy: 0.3333
# Epoch 382/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.2386 - accuracy: 0.9222 - val_loss: 5.2897 - val_accuracy: 0.4167
# Epoch 383/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3566 - accuracy: 0.8924 - val_loss: 4.1864 - val_accuracy: 0.2500
# Epoch 384/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2723 - accuracy: 0.9056 - val_loss: 3.5095 - val_accuracy: 0.4167
# Epoch 385/400
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2140 - accuracy: 0.9156 - val_loss: 3.6303 - val_accuracy: 0.3056
# Epoch 386/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2062 - accuracy: 0.9288 - val_loss: 3.8181 - val_accuracy: 0.4167
# Epoch 387/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1504 - accuracy: 0.9470 - val_loss: 4.2983 - val_accuracy: 0.4167
# Epoch 388/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1368 - accuracy: 0.9387 - val_loss: 3.8122 - val_accuracy: 0.4167
# Epoch 389/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1206 - accuracy: 0.9454 - val_loss: 4.3840 - val_accuracy: 0.3611
# Epoch 390/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1251 - accuracy: 0.9404 - val_loss: 4.1862 - val_accuracy: 0.4444
# Epoch 391/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1152 - accuracy: 0.9470 - val_loss: 4.5624 - val_accuracy: 0.3889
# Epoch 392/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0970 - accuracy: 0.9652 - val_loss: 4.6414 - val_accuracy: 0.3333
# Epoch 393/400
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0577 - accuracy: 0.9801 - val_loss: 4.9772 - val_accuracy: 0.4167
# Epoch 394/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0370 - accuracy: 0.9868 - val_loss: 4.9996 - val_accuracy: 0.4167
# Epoch 395/400
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0326 - accuracy: 0.9884 - val_loss: 5.2408 - val_accuracy: 0.4167
# Epoch 396/400
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0296 - accuracy: 0.9901 - val_loss: 5.1762 - val_accuracy: 0.4444
# Epoch 397/400
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0177 - accuracy: 0.9934 - val_loss: 5.3053 - val_accuracy: 0.4167
# Epoch 398/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9901 - val_loss: 5.4617 - val_accuracy: 0.4444
# Epoch 399/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 0.9917 - val_loss: 5.4117 - val_accuracy: 0.4167
# Epoch 400/400
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9901 - val_loss: 5.5474 - val_accuracy: 0.4444

# %% [markdown]
# ### epoch에 따른 accuracy 변화 그래프 확인

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

# %% [markdown]
# ### 모델 평가
# 데이터 대부분이 분포되어 있는 클래스 0을 제외하고, 나머지 데이터를 가지고 평가

# %%
# 클래스가 1 이상에 해당하는 데이터만 t_target에 할당
# 해당 인덱스의 input 데이터도 t_input에 할당

t_target_index = pd.DataFrame(test_target)[test_target>=1].index
t_target = test_target[test_target>=1]
t_input = test_input.reset_index(drop=True)
t_input = t_input.loc[t_target_index]

model.evaluate(t_input, t_target)
# Out:
# 1/1 [==============================] - 0s 90ms/step - loss: 5.6456 - accuracy: 0.4483
# [5.645562171936035, 0.4482758641242981]

# %% [markdown]
# #### test 세트로 모델 predict 수행

# %%
a = model.predict(test_input)
[np.where(i == max(i))[0][0] for i in a][:10]
# Out:
# [4, 4, 2, 2, 3, 3, 1, 0, 2, 2]

# %%
list(test_target[:10])
# Out:
# [4, 4, 3, 2, 2, 2, 0, 1, 0, 2]

# %% [markdown]
# ### 모델 저장

# %%
model.save('cls_model.h5')
