# %% [markdown]
# ### pip install & import

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
#import pandas_profiling
import datetime

# %%
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder

from sklearn.preprocessing import MinMaxScaler

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestRegressor

# from xgboost import XGBRFRegressor
from sklearn.model_selection import cross_validate

# %% [markdown]
# ### 최종데이터 불러오기

# %%
# movie_final_회귀 = pd.read_csv('../3_merge_top300/movie_final_reg.csv',encoding='utf-8')
movie_final_분류 = pd.read_csv('../3_merge_top300/movie_final_cls.csv',encoding='utf-8')

# %% [markdown]
# ## 원핫인코딩

# %%
# 원핫인코딩

# movie_labels = pd.get_dummies(movie_final,columns = ['국적','장르','등급','계절'])

# %%
# 독립 변수와 종속 변수 나눔

# 독립 = movie_DL[['감독_흥행', '배급사_흥행', '국적_기타', '국적_독일', '국적_미국',
#        '국적_영국', '국적_일본', '국적_중국', '국적_프랑스', '국적_한국', '장르_SF', '장르_가족', '장르_공연',
#        '장르_공포(호러)', '장르_기타', '장르_다큐멘터리', '장르_드라마', '장르_멜로/로맨스', '장르_뮤지컬',
#        '장르_미스터리', '장르_범죄', '장르_사극', '장르_서부극(웨스턴)', '장르_성인물(에로)', '장르_스릴러',
#        '장르_애니메이션', '장르_액션', '장르_어드벤처', '장르_전쟁', '장르_코미디', '장르_판타지',
#        '등급_12세관람가', '등급_15세관람가', '등급_전체관람가', '등급_청소년관람불가', '계절_가을', '계절_겨울',
#        '계절_봄', '계절_여름']] 
# 종속 = movie_DL[['전국 관객수']]

# %% [markdown]
# # 스케일링

# %%
from sklearn.preprocessing import RobustScaler

# 객체생성
robust_scaler = RobustScaler()

# *** 만약 특정 열의 스케일링을 하고 싶은 경우 ***
A_n = robust_scaler.fit_transform(movie_final_분류['전국 스크린수'].values.reshape(-1,1))
movie_final_분류.insert(0, '전국 스크린수_scaled', A_n)
# movie_final_분류.drop(['전국 스크린수'], axis=1, inplace=False)

A_n1 = robust_scaler.fit_transform(movie_final_분류['총 관객수'].values.reshape(-1,1))
movie_final_분류.insert(0, '총 관객수_scaled', A_n1)
# movie_final_분류.drop(['총 관객수'], axis=1, inplace=False)

# %%
movie_final_분류.columns
# Out:
# Index(['총 관객수_scaled', '전국 스크린수_scaled', 'Unnamed: 0', '순번', '영화명', '감독',
#        '배급사', '개봉일', '영화형태', '국적', '전국 스크린수', '전국 매출액', '전국 관객수', '서울 매출액',
#        '서울 관객수', '장르', '등급', '영화구분', '연도', '월', '계절', '총 관객수', '코로나', '출연',
#        '평점', '감독_흥행', '배급사_흥행', '주연배우_흥행'],
#       dtype='object')

# %% [markdown]
# ## 라벨링

# %%
from sklearn.preprocessing import LabelEncoder

le_form = LabelEncoder()
le_nation = LabelEncoder()
le_genre = LabelEncoder()
le_rating = LabelEncoder()
le_class = LabelEncoder()
le_season = LabelEncoder()

movie_labels = movie_final_분류.copy()
movie_labels['영화형태'] = le_form.fit_transform(movie_final_분류['영화형태'])
movie_labels['국적'] = le_nation.fit_transform(movie_final_분류['국적'])
movie_labels['장르'] = le_genre.fit_transform(movie_final_분류['장르'])
movie_labels['등급'] = le_rating.fit_transform(movie_final_분류['등급'])
movie_labels['영화구분'] = le_class.fit_transform(movie_final_분류['영화구분'])
movie_labels['계절'] = le_season.fit_transform(movie_final_분류['계절'])
movie_labels.drop(['Unnamed: 0'],axis=1,inplace=True)
movie_labels.head(3)
# Out:
#    총 관객수_scaled  전국 스크린수_scaled  순번        영화명   감독       배급사         개봉일  \
# 0      0.027876        1.397641   1         명량  김한민    씨제이이엔엠  2014-07-30
# 1      0.216263        2.056445   2       극한직업  이병헌    씨제이이엔엠  2019-01-23
# 2      0.105881        1.945240   3  신과함께-죄와 벌  김용화  롯데엔터테인먼트  2017-12-20
#
#    영화형태  국적  전국 스크린수  ...    연도   월 계절      총 관객수  코로나  \
# 0     0   7     1587  ...  2014   7  3  215068958    0
# 1     0   7     1978  ...  2019   1  1  226678777    0
# 2     0   7     1912  ...  2017  12  1  219876227    0
#
#                                            출연    평점  감독_흥행  배급사_흥행  주연배우_흥행
# 0                       ['최민식', '류승룡', '조진웅']  8.44      9      10       20
# 1          ['류승룡', '이하늬', '진선규', '이동휘', '공명']  8.51      4      10       16
# 2  ['하정우', '차태현', '주지훈', '김향기', '김동욱', '마동석']  7.83      9       9       40
#
# [3 rows x 27 columns]

# %%
# movie_labels[movie_labels['연도']!=2023]
# Out:
#        총 관객수_1  전국 스크린수_1    순번             영화명         감독         배급사  \
# 0     0.018839   1.959732  2575          미니특공대X        이영준     삼지애니메이션
# 1    -0.854008  -0.033557  2578             알파독     닉 카사베츠        싸이더스
# 2    -1.463612   3.348993  2583             엘비스     바즈 루어만  워너브러더스 코리아
# 3     0.068802   0.261745  2584             라이언    가스 데이비스       이수C&E
# 4    -0.024587   0.369128  2585  로덴시아: 마법왕국의 전설  데이비드 비스바노       영화사 빅
# ...        ...        ...   ...             ...        ...         ...
# 1408 -2.226178  -0.241611  4856            안티고네    소피 드라스프     그린나래미디어
# 1409  0.166161  -0.255034  4858            신문기자   후지이 미치히토     팝엔터테인먼트
# 1410  0.166161  -0.442953  4859    사랑은 비가 갠 뒤처럼    나가이 아키라       디스테이션
# 1411 -1.463612  -0.510067  4860         극장판 시그널   하시모토 하지메   트윈플러스파트너스
# 1412  0.068802  -0.651007  4861              눈발        조재민      리틀빅픽쳐스
#
#              개봉일  영화형태  국적      전국 매출액  ...  영화구분    연도   월  계절  코로나  \
# 0     2018-03-22     2   7   744858200  ...     1  2018   3   2    0
# 1     2009-01-29     2   2   648950794  ...     1  2009   1   1    0
# 2     2022-07-13     2   2  1070700628  ...     1  2022   7   3    1
# 3     2017-02-01     2   0   736334100  ...     0  2017   2   1    0
# 4     2013-10-02     2   0   632768500  ...     0  2013  10   0    0
# ...          ...   ...  ..         ...  ...   ...   ...  ..  ..  ...
# 1408  2020-11-19     2   0    88869360  ...     0  2020  11   0    1
# 1409  2019-10-17     2   4    81471660  ...     0  2019  10   0    0
# 1410  2019-02-07     2   4    84113620  ...     0  2019   2   1    0
# 1411  2022-03-31     2   4    61115200  ...     0  2022   3   2    1
# 1412  2017-03-01     2   7    84806300  ...     0  2017   3   2    0
#
#                                                      출연    평점  감독_흥행  배급사_흥행  \
# 0                          ['엄상현', '전태열', '이소영', '신용우']  7.55      0       0
# 1     ['에밀 허쉬', '저스틴 팀버레이크', '벤 포스터', '안톤 옐친', '아만다 ...  6.06      0       6
# 2                                  ['오스틴 버틀러', '톰 행크스']  8.83      0      10
# 3     ['데브 파텔', '루니 마라', '니콜 키드먼', '데이비드 웬햄', '써니 파와르']  9.24      0       0
# 4     ['헤르난 브라보', '나탈리아 로스미나티', '엔리크 포셀라나', '리카르도 알라...  7.43      0       0
# ...                                                 ...   ...    ...     ...
# 1408                ['나에마 리치', '라와드 엘-제인', '앙투안느 데로쉬에']  8.05      0       0
# 1409                                 ['심은경', '마츠자카 토리']  8.01      0       0
# 1410                              ['고마츠 나나', '오오이즈미 요']  8.77      0       8
# 1411                ['사카구치 켄타로', '키타무라 카즈키', '키치세 미치코']  6.16      0       0
# 1412                                       ['진영', '지우']  7.73      0       0
#
#       주연배우_흥행
# 0           0
# 1           6
# 2           5
# 3           0
# 4           0
# ...       ...
# 1408        0
# 1409        9
# 1410        0
# 1411        0
# 1412       10
#
# [1394 rows x 25 columns]

# %% [markdown]
# ### 데이터분배
# 1) movie_labels_etc : train과 val data
# 2) movie_labels_2023 : test data

# %%
# movie_labels_2023 = movie_labels[movie_labels['연도']==2023]
# movie_labels_etc = movie_labels[movie_labels['연도']!=2023]
# display(movie_labels_etc.head(),
# movie_labels_2023.head())
# Out:
#    총 관객수_scaled  전국 스크린수_scaled  순번         영화명      감독            배급사  \
# 0      0.027876        1.397641   1          명량     김한민         씨제이이엔엠
# 1      0.216263        2.056445   2        극한직업     이병헌         씨제이이엔엠
# 2      0.105881        1.945240   3   신과함께-죄와 벌     김용화       롯데엔터테인먼트
# 3      0.027876        0.351306   4        국제시장     윤제균         씨제이이엔엠
# 4      0.216263        3.500421   5  어벤져스: 엔드게임  안소니 루소  월트디즈니스튜디오스코리아
#
#           개봉일  영화형태  국적  전국 스크린수  ...    연도   월 계절      총 관객수  코로나  \
# 0  2014-07-30     0   7     1587  ...  2014   7  3  215068958    0
# 1  2019-01-23     0   7     1978  ...  2019   1  1  226678777    0
# 2  2017-12-20     0   7     1912  ...  2017  12  1  219876227    0
# 3  2014-12-17     0   7      966  ...  2014  12  1  215068958    0
# 4  2019-04-24     0   2     2835  ...  2019   4  2  226678777    0
#
#                                                   출연    평점  감독_흥행  배급사_흥행  \
# 0                              ['최민식', '류승룡', '조진웅']  8.44      9      10
# 1                 ['류승룡', '이하늬', '진선규', '이동휘', '공명']  8.51      4      10
# 2         ['하정우', '차태현', '주지훈', '김향기', '김동욱', '마동석']  7.83      9       9
# 3                       ['황정민', '김윤진', '오달수', '정진영']  9.02     10      10
# 4  ['로버트 다우니 주니어', '크리스 에반스', '크리스 헴스워스', '마크 러팔로...  9.38     10      10
#
#    주연배우_흥행
# 0       20
# 1       16
# 2       40
# 3       17
# 4      106
#
# [5 rows x 27 columns]
#      총 관객수_scaled  전국 스크린수_scaled   순번                영화명       감독  \
# 398      -1.63151        0.895535  543                 교섭      임순례
# 485      -1.63151        2.245156  671    앤트맨과 와스프: 퀀텀매니아   페이튼 리드
# 690      -1.63151        0.280539  984  장화신은 고양이: 끝내주는 모험  조엘 크로포드
#
#                   배급사         개봉일  영화형태  국적  전국 스크린수  ...    연도  월 계절  \
# 398       플러스엠 엔터테인먼트  2023-01-18     0   7     1289  ...  2023  1  1
# 485     월트디즈니스튜디오스코리아  2023-02-15     0   2     2090  ...  2023  2  1
# 690  유니버설픽쳐스인터내셔널 코리아  2023-01-04     0   2      924  ...  2023  1  1
#
#          총 관객수  코로나                                                 출연    평점  \
# 398  112805094    0                               ['황정민', '현빈', '강기영']  5.79
# 485  112805094    0  ['폴 러드', '에반젤린 릴리', '미셸 파이퍼', '마이클 더글라스', '조나단...  7.09
# 690  112805094    0  ['안토니오 반데라스', '크리스 밀러', '셀마 헤이엑', '올리비아 콜맨', '...  8.83
#
#      감독_흥행  배급사_흥행  주연배우_흥행
# 398      6       9       19
# 485      8      10       34
# 690      0       8       14
#
# [3 rows x 27 columns]

# %% [markdown]
# ### 변수 정리
# 1. 사용하지 않는 컬럼 제거
# 2. 독립변수와 종속변수 설정

# %%
# # 사용하지 않는 컬럼 제거

# not_used = ['영화명', '감독', '배급사', '영화형태', '개봉일', '영화구분', '월']

# movie_DL = movie_labels_etc.drop(not_used, axis=1)      # 2003~2022 데이터 main
# movie_DL2 = movie_labels_2023.drop(not_used, axis=1)    # 2023년 test

# %%
# 사용하지 않는 컬럼 제거

not_used = ['영화명', '감독', '배급사', '영화형태', '개봉일', '영화구분', '월']

movie_DL = movie_labels.drop(not_used, axis=1)
movie_DL.head()
# Out:
#    총 관객수_scaled  전국 스크린수_scaled  순번  국적  전국 스크린수        전국 매출액    전국 관객수  \
# 0      0.027876        1.397641   1   7     1587  135748398910  17613682
# 1      0.216263        2.056445   2   7     1978  139647979516  16264944
# 2      0.105881        1.945240   3   7     1912  115698654137  14410754
# 3      0.027876        0.351306   4   7      966  110828014630  14245998
# 4      0.216263        3.500421   5   2     2835  122182694160  13934592
#
#            서울 매출액     서울 관객수  장르  등급    연도  계절      총 관객수  코로나  \
# 0  33,121,225,810  4,163,666   9   1  2014   3  215068958    0
# 1  31,858,660,536  3,638,287  16   1  2019   1  226678777    0
# 2  27,530,825,087  3,346,172  17   0  2017   1  219876227    0
# 3  25,842,519,330  3,233,946   4   0  2014   1  215068958    0
# 4  33,577,136,860  3,597,963  13   0  2019   2  226678777    0
#
#                                                   출연    평점  감독_흥행  배급사_흥행  \
# 0                              ['최민식', '류승룡', '조진웅']  8.44      9      10
# 1                 ['류승룡', '이하늬', '진선규', '이동휘', '공명']  8.51      4      10
# 2         ['하정우', '차태현', '주지훈', '김향기', '김동욱', '마동석']  7.83      9       9
# 3                       ['황정민', '김윤진', '오달수', '정진영']  9.02     10      10
# 4  ['로버트 다우니 주니어', '크리스 에반스', '크리스 헴스워스', '마크 러팔로...  9.38     10      10
#
#    주연배우_흥행
# 0       20
# 1       16
# 2       40
# 3       17
# 4      106

# %%
# 국적 => 국내 vs 해외
# 관객비율.. 2023년 데이터 총 관객수 몰라....
# 비율 말고 총 관객수를 쓰자
# 총관객수 defqult를 2022년으로 해서 2023년 총관객수 채우면 어때?

# %%
# # 독립 변수와 종속 변수 나눔

# 종속 = movie_DL[['전국 관객수']].copy()
# 종속['전국 관객수'] = 종속['전국 관객수'] / 1000 

# 종속_2023 = movie_DL2[['전국 관객수']].copy()
# 종속_2023['전국 관객수'] = 종속_2023['전국 관객수'] / 1000 


# 독립 = movie_DL[['장르', '등급', '감독_흥행','총 관객수_scaled',
#                '배급사_흥행','주연배우_흥행','계절', '전국 스크린수_scaled','연도','코로나']].copy()

# 독립_2023 = movie_DL2[['장르', '등급', '감독_흥행','총 관객수_scaled',
#                '배급사_흥행','주연배우_흥행','계절', '전국 스크린수_scaled','연도','코로나']].copy()

# display(독립.head(), 독립_2023.head())
# Out:
#    장르  등급  감독_흥행  총 관객수_scaled  배급사_흥행  주연배우_흥행  계절  전국 스크린수_scaled    연도  코로나
# 0   9   1      9      0.027876      10       20   3        1.397641  2014    0
# 1  16   1      4      0.216263      10       16   1        2.056445  2019    0
# 2  17   0      9      0.105881       9       40   1        1.945240  2017    0
# 3   4   0     10      0.027876      10       17   1        0.351306  2014    0
# 4  13   0     10      0.216263      10      106   2        3.500421  2019    0
#      장르  등급  감독_흥행  총 관객수_scaled  배급사_흥행  주연배우_흥행  계절  전국 스크린수_scaled    연도  \
# 398   4   0      6      -1.63151       9       19   1        0.895535  2023
# 485  13   0      8      -1.63151      10       34   1        2.245156  2023
# 690  12   2      0      -1.63151       8       14   1        0.280539  2023
#
#      코로나
# 398    0
# 485    0
# 690    0

# %%
독립 = movie_DL[['장르', '등급', '감독_흥행','총 관객수_scaled',
               '배급사_흥행','주연배우_흥행','계절', '전국 스크린수_scaled','연도','코로나']].copy()

종속 = movie_DL[['전국 관객수']].copy()

display(독립.info(), 종속.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   장르              708 non-null    int32
#  1   등급              708 non-null    int32
#  2   감독_흥행           708 non-null    int64
#  3   총 관객수_scaled    708 non-null    float64
#  4   배급사_흥행          708 non-null    int64
#  5   주연배우_흥행         708 non-null    int64
#  6   계절              708 non-null    int32
#  7   전국 스크린수_scaled  708 non-null    float64
#  8   연도              708 non-null    int64
#  9   코로나             708 non-null    int64
# dtypes: float64(2), int32(3), int64(5)
# memory usage: 47.1 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전국 관객수  708 non-null    int64
# dtypes: int64(1)
# memory usage: 5.7 KB
# None
# None

# %% [markdown]
# ## train, test 데이터 나누기

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(독립, 종속, test_size=0.20)

# %%
train_input, val_input, train_target, val_target = train_test_split(train_input, train_target, test_size=0.20)
print(len(train_input), len(val_input), len(test_input))
# Out:
# 452 114 142

# %%
# train, validation 데이터 나눔

from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(독립,종속,test_size=0.25,random_state=42)

# %% [markdown]
# ## target 클래스 분류하기

# %%
display(
    len(train_target[train_target['전국 관객수']<1000000]),
    len(train_target[(train_target['전국 관객수']>1000000) & (train_target['전국 관객수']<1400000)]),
    len(train_target[(train_target['전국 관객수']>1400000) & (train_target['전국 관객수']<2000000)]),
    len(train_target[(train_target['전국 관객수']>2000000) & (train_target['전국 관객수']<3000000)]),
    len(train_target[(train_target['전국 관객수']>3000000) & (train_target['전국 관객수']<5000000)]),
    len(train_target[train_target['전국 관객수']>5000000])
)
# Out:
# 67
# 84
# 77
# 99
# 66
# 59

# %%
# movie_resize_분류['코로나'] = np.where((movie_resize_분류['연도'].values >=2020) & (movie_resize_분류['연도'].values <=2022) , 1, 0)

import numpy as np

train_target['분류클래스'] = np.where((train_target['전국 관객수'].values<1000000), 1, 
                                 np.where((train_target['전국 관객수'].values>1000000) & (train_target['전국 관객수'].values<1400000), 2,
                                          np.where((train_target['전국 관객수'].values>1400000) & (train_target['전국 관객수'].values<2000000), 3,
                                                   np.where((train_target['전국 관객수'].values>2000000) & (train_target['전국 관객수'].values<3000000), 4,
                                                            np.where((train_target['전국 관객수'].values>3000000) & (train_target['전국 관객수'].values<5000000), 5, 6))))
)
train_target['분류클래스'].unique()
train_target[['전국 관객수','분류클래스']]
# Out:
#        전국 관객수  분류클래스
# 287   2325715      4
# 35    8252669      6
# 339   2048137      4
# 570   1114941      2
# 22   10313086      6
# ..        ...    ...
# 40    7784807      6
# 703    806924      1
# 648    918183      1
# 19   11211880      6
# 377   1823116      3
#
# [452 rows x 2 columns]

# %%
val_target['분류클래스'] = np.where((val_target['전국 관객수'].values<1000000), 1, 
                                 np.where((val_target['전국 관객수'].values>1000000) & (val_target['전국 관객수'].values<1400000), 2,
                                          np.where((val_target['전국 관객수'].values>1400000) & (val_target['전국 관객수'].values<2000000), 3,
                                                   np.where((val_target['전국 관객수'].values>2000000) & (val_target['전국 관객수'].values<3000000), 4,
                                                            np.where((val_target['전국 관객수'].values>3000000) & (val_target['전국 관객수'].values<5000000), 5, 6))))
)
val_target['분류클래스'].unique()
# val_target[['전국 관객수','분류클래스']]
# Out:
# array([1, 6, 3, 5, 2, 4])

# %%
test_target['분류클래스'] = np.where((test_target['전국 관객수'].values<1000000), 1, 
                                 np.where((test_target['전국 관객수'].values>1000000) & (test_target['전국 관객수'].values<1400000), 2,
                                          np.where((test_target['전국 관객수'].values>1400000) & (test_target['전국 관객수'].values<2000000), 3,
                                                   np.where((test_target['전국 관객수'].values>2000000) & (test_target['전국 관객수'].values<3000000), 4,
                                                            np.where((test_target['전국 관객수'].values>3000000) & (test_target['전국 관객수'].values<5000000), 5, 6))))
)
test_target['분류클래스'].unique()
# test_target[['전국 관객수','분류클래스']]
# Out:
# array([6, 2, 3, 5, 4, 1])

# %%
# # 값 스케일링

# from sklearn.preprocessing import StandardScaler
# ss = StandardScaler()
# ss.fit(train_input)
# train_scaled = ss.transform(train_input)
# test_scaled = ss.transform(test_input)

# %% [markdown]
# # 딥러닝

# %%
# 딥러닝 층 여기가 중요

X = tf.keras.layers.Input(shape=[10])

H = tf.keras.layers.Dense(128)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation(tf.nn.swish)(H)

H = tf.keras.layers.Dense(128)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation(tf.nn.swish)(H)

H = tf.keras.layers.Dense(128)(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation(tf.nn.swish)(H)
dropout = tf.keras.layers.Dropout(rate=0.3)(H)

Y = tf.keras.layers.Dense(1)(dropout)
model = tf.keras.models.Model(X,Y)
sgd = tf.keras.optimizers.Adam(learning_rate=0.01,beta_1=0.8,beta_2=0.85)
# sgd = tf.keras.optimizers.SGD(learning_rate=0.1,momentum=0.7)
model.compile(optimizer=sgd,loss='mae')

# %%
# 훈련

history = model.fit(train_input,train_target,batch_size=128,epochs=100,validation_data=(test_input,test_target))
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 44ms/step - loss: 36.4022 - val_loss: 760.4990
# Epoch 2/100
# 9/9 [==============================] - 0s 11ms/step - loss: 32.3912 - val_loss: 1629.3385
# Epoch 3/100
# 9/9 [==============================] - 0s 9ms/step - loss: 27.5266 - val_loss: 1268.6385
# Epoch 4/100
# 9/9 [==============================] - 0s 10ms/step - loss: 22.6644 - val_loss: 1046.0258
# Epoch 5/100
# 9/9 [==============================] - 0s 10ms/step - loss: 18.6863 - val_loss: 898.2750
# Epoch 6/100
# 9/9 [==============================] - 0s 10ms/step - loss: 16.6958 - val_loss: 1548.5502
# Epoch 7/100
# 9/9 [==============================] - 0s 11ms/step - loss: 16.3074 - val_loss: 1385.3956
# Epoch 8/100
# 9/9 [==============================] - 0s 10ms/step - loss: 16.0943 - val_loss: 1119.5958
# Epoch 9/100
# 9/9 [==============================] - 0s 11ms/step - loss: 15.9185 - val_loss: 409.8743
# Epoch 10/100
# 9/9 [==============================] - 0s 12ms/step - loss: 15.6927 - val_loss: 405.6109
# Epoch 11/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.4400 - val_loss: 203.2394
# Epoch 12/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.6616 - val_loss: 231.8503
# Epoch 13/100
# 9/9 [==============================] - 0s 9ms/step - loss: 15.5373 - val_loss: 201.6970
# Epoch 14/100
# 9/9 [==============================] - 0s 9ms/step - loss: 15.4775 - val_loss: 95.6815
# Epoch 15/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.2715 - val_loss: 88.4575
# Epoch 16/100
# 9/9 [==============================] - 0s 11ms/step - loss: 15.1136 - val_loss: 61.7620
# Epoch 17/100
# 9/9 [==============================] - 0s 20ms/step - loss: 15.2740 - val_loss: 77.4349
# Epoch 18/100
# 9/9 [==============================] - 0s 12ms/step - loss: 15.1357 - val_loss: 45.3015
# Epoch 19/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.1795 - val_loss: 23.7693
# Epoch 20/100
# 9/9 [==============================] - 0s 9ms/step - loss: 15.1669 - val_loss: 22.3031
# Epoch 21/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.1919 - val_loss: 62.0996
# Epoch 22/100
# 9/9 [==============================] - 0s 13ms/step - loss: 15.5327 - val_loss: 135.8847
# Epoch 23/100
# 9/9 [==============================] - 0s 9ms/step - loss: 15.2464 - val_loss: 103.1416
# Epoch 24/100
# 9/9 [==============================] - 0s 11ms/step - loss: 15.3081 - val_loss: 26.8069
# Epoch 25/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.9562 - val_loss: 57.1645
# Epoch 26/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.8589 - val_loss: 21.3237
# Epoch 27/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.0691 - val_loss: 149.5799
# Epoch 28/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.8248 - val_loss: 138.1215
# Epoch 29/100
# 9/9 [==============================] - 0s 11ms/step - loss: 15.0130 - val_loss: 96.9720
# Epoch 30/100
# 9/9 [==============================] - 0s 12ms/step - loss: 15.0796 - val_loss: 72.7832
# Epoch 31/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.7841 - val_loss: 25.8561
# Epoch 32/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.9313 - val_loss: 99.0099
# Epoch 33/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.2771 - val_loss: 40.9142
# Epoch 34/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.1440 - val_loss: 40.2116
# Epoch 35/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.6633 - val_loss: 51.7893
# Epoch 36/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.7217 - val_loss: 28.0157
# Epoch 37/100
# 9/9 [==============================] - 0s 10ms/step - loss: 15.1863 - val_loss: 29.5400
# Epoch 38/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.6579 - val_loss: 26.5458
# Epoch 39/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.8109 - val_loss: 28.0463
# Epoch 40/100
# 9/9 [==============================] - 0s 9ms/step - loss: 14.7053 - val_loss: 61.0285
# Epoch 41/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.6410 - val_loss: 56.3502
# Epoch 42/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.8376 - val_loss: 71.3122
# Epoch 43/100
# 9/9 [==============================] - 0s 9ms/step - loss: 14.6998 - val_loss: 20.6779
# Epoch 44/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.6232 - val_loss: 23.1931
# Epoch 45/100
# 9/9 [==============================] - 0s 14ms/step - loss: 14.7194 - val_loss: 45.4691
# Epoch 46/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.8252 - val_loss: 205.9450
# Epoch 47/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.4877 - val_loss: 161.8068
# Epoch 48/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.9865 - val_loss: 48.5201
# Epoch 49/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.5521 - val_loss: 127.1325
# Epoch 50/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.7183 - val_loss: 425.0623
# Epoch 51/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.2983 - val_loss: 250.7744
# Epoch 52/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.6777 - val_loss: 93.4248
# Epoch 53/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.3982 - val_loss: 571.4874
# Epoch 54/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.8318 - val_loss: 25.3239
# Epoch 55/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.6248 - val_loss: 41.9551
# Epoch 56/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.5574 - val_loss: 26.6473
# Epoch 57/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.4696 - val_loss: 24.8857
# Epoch 58/100
# 9/9 [==============================] - 0s 22ms/step - loss: 14.4756 - val_loss: 52.5364
# Epoch 59/100
# 9/9 [==============================] - 0s 13ms/step - loss: 14.5950 - val_loss: 242.8506
# Epoch 60/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.7044 - val_loss: 43.6982
# Epoch 61/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.4482 - val_loss: 45.5961
# Epoch 62/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.6115 - val_loss: 67.5447
# Epoch 63/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.5376 - val_loss: 277.5716
# Epoch 64/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.1799 - val_loss: 199.7305
# Epoch 65/100
# 9/9 [==============================] - 0s 9ms/step - loss: 14.3978 - val_loss: 24.7558
# Epoch 66/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.7941 - val_loss: 58.8814
# Epoch 67/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.2105 - val_loss: 55.5682
# Epoch 68/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.3094 - val_loss: 42.9969
# Epoch 69/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.1912 - val_loss: 22.1605
# Epoch 70/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.1216 - val_loss: 21.5174
# Epoch 71/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.3073 - val_loss: 117.0566
# Epoch 72/100
# 9/9 [==============================] - 0s 16ms/step - loss: 14.4399 - val_loss: 204.2178
# Epoch 73/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.3021 - val_loss: 209.4319
# Epoch 74/100
# 9/9 [==============================] - 0s 10ms/step - loss: 13.9662 - val_loss: 91.7711
# Epoch 75/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.3215 - val_loss: 248.5319
# Epoch 76/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.2483 - val_loss: 129.4534
# Epoch 77/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.2254 - val_loss: 72.5982
# Epoch 78/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.0488 - val_loss: 384.8842
# Epoch 79/100
# 9/9 [==============================] - 0s 12ms/step - loss: 14.2667 - val_loss: 52.3880
# Epoch 80/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.2286 - val_loss: 161.8289
# Epoch 81/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.0396 - val_loss: 61.4864
# Epoch 82/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.2228 - val_loss: 26.6402
# Epoch 83/100
# 9/9 [==============================] - 0s 10ms/step - loss: 13.8743 - val_loss: 61.1275
# Epoch 84/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.2594 - val_loss: 24.4428
# Epoch 85/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.1344 - val_loss: 23.5449
# Epoch 86/100
# 9/9 [==============================] - 0s 11ms/step - loss: 13.8900 - val_loss: 19.7164
# Epoch 87/100
# 9/9 [==============================] - 0s 10ms/step - loss: 13.9999 - val_loss: 232.9207
# Epoch 88/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.2101 - val_loss: 24.5251
# Epoch 89/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.2260 - val_loss: 48.1718
# Epoch 90/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.3092 - val_loss: 51.0928
# Epoch 91/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.2526 - val_loss: 30.1076
# Epoch 92/100
# 9/9 [==============================] - 0s 11ms/step - loss: 13.8779 - val_loss: 49.7220
# Epoch 93/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.2661 - val_loss: 124.9329
# Epoch 94/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.0879 - val_loss: 42.4269
# Epoch 95/100
# 9/9 [==============================] - 0s 10ms/step - loss: 13.9347 - val_loss: 20.5651
# Epoch 96/100
# 9/9 [==============================] - 0s 10ms/step - loss: 14.0110 - val_loss: 246.8364
# Epoch 97/100
# 9/9 [==============================] - 0s 10ms/step - loss: 13.7949 - val_loss: 36.0510
# Epoch 98/100
# 9/9 [==============================] - 0s 19ms/step - loss: 13.9984 - val_loss: 20.0571
# Epoch 99/100
# 9/9 [==============================] - 0s 12ms/step - loss: 14.0950 - val_loss: 22.7201
# Epoch 100/100
# 9/9 [==============================] - 0s 11ms/step - loss: 14.1953 - val_loss: 94.8077

# %%
# 확인용도
model.predict(train_input[:5])
# Out:
# 1/1 [==============================] - 0s 123ms/step
# array([[131.46555 ],
#        [127.31804 ],
#        [128.48778 ],
#        [127.678375],
#        [124.575195]], dtype=float32)

# %%
# 여기랑 비슷한지 보기
train_target[:5]
# Out:
#       전국 관객수
# 952   20.175
# 335   56.282
# 933   21.071
# 1354  10.854
# 1007  18.501

# %% [markdown]
# ### test data 확인용도

# %%
# 확인용도

# 오차율 몇 %로...?
pred = model.predict(독립_2023).round(0)
# 여기랑 비슷한지 보기
종속_2023['pred'] = pred
종속_2023['오차율'] = (abs(종속_2023['전국 관객수'] - 종속_2023['pred'])) / 종속_2023['전국 관객수'] * 100
len(종속_2023.loc[종속_2023['오차율']<20])
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 0

# %%
종속_2023
# Out:
#        전국 관객수    pred         오차율
# 398  1720.865  2441.0   41.847269
# 485  1376.493  4026.0  192.482417
# 690   829.268  1706.0  105.723602
